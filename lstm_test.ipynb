# %%
from function_file.time_series import time_series_dataframe

df = time_series_dataframe()
df
# Out:
#            TEMP  label    TIME
# 0       286.797      1       0
# 1       287.082      1       1
# 2       285.938      1       2
# 3       285.772      1       3
# 4       286.357      1       4
# ...         ...    ...     ...
# 906535  768.756      9  906535
# 906536  768.964      9  906536
# 906537  768.936      9  906537
# 906538  769.067      9  906538
# 906539  769.001      9  906539
#
# [906540 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(40,10))
sns.lineplot(x = 'TIME', y = 'TEMP', data = df)
plt.show()

# %%
train_len = int(len(df) * 0.7)
train_data = df[:train_len]
test_data = df[train_len:]

# %%
plt.figure(figsize=(40,10))
sns.lineplot(x = 'TIME', y = 'TEMP', data = test_data)
plt.show()

# %%
from function_file import transformer

test_result, truth = transformer.train_transformer()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/kim/hanhwa-1/lstm_test.ipynb 셀 5 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kim/hanhwa-1/lstm_test.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> from function_file import transformer
#       <a href='vscode-notebook-cell:/Users/kim/hanhwa-1/lstm_test.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> test_result, truth = transformer.train_transformer()
#
# File ~/hanhwa-1/function_file/transformer.py:8, in <module>
#       6 import matplotlib.pyplot as plt
#       7 import warnings
# ----> 8 from function_file.ML_functions import *
#      11 class PositionalEncoding(nn.Module):
#      12     def __init__(self, d_model, max_len=5000):
#
# File ~/hanhwa-1/function_file/ML_functions.py:4, in <module>
#       2 import numpy as np
#       3 import os
# ----> 4 from sklearn.neighbors import KNeighborsClassifier
# ...
