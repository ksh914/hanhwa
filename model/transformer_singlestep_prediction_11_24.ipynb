# %%
cd ..
# Out:
# c:\Users\Sejong\Desktop\hanhwa

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import math
from matplotlib import pyplot
import warnings
warnings.filterwarnings('ignore')
torch.manual_seed(0)
np.random.seed(0)

# S is the source sequence length
# T is the target sequence length
# N is the batch size
# E is the feature number

#src = torch.rand((10, 32, 512)) # (S,N,E) 
#tgt = torch.rand((20, 32, 512)) # (T,N,E)
#out = transformer_model(src, tgt)

input_window = 60 # number of input steps
output_window = 1 # number of prediction steps, in this model its fixed to one
block_len = input_window + output_window # for one input-output pair
batch_size = 512
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()       
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(max_len, dtype=torch.float).unsqueeze(1)
        # div_term = torch.exp(
        #     torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
        # )
        div_term = 1 / (10000 ** ((2 * np.arange(d_model)) / d_model))
        #div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term[0::2])
        pe[:, 1::2] = torch.cos(position * div_term[1::2])

        pe = pe.unsqueeze(0).transpose(0, 1) # [5000, 1, d_model],so need seq-len <= 5000
        #pe.requires_grad = False
        self.register_buffer('pe', pe)

    def forward(self, x):
        # print(self.pe[:x.size(0), :].repeat(1,x.shape[1],1).shape ,'---',x.shape)
        # dimension 1 maybe inequal batchsize
        return x + self.pe[:x.size(0), :].repeat(1,x.shape[1],1)
          

class TransAm(nn.Module):
    def __init__(self,feature_size=250,num_layers=1,dropout=0.1):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'
        self.input_embedding  = nn.Linear(1,feature_size)
        self.src_mask = None

        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        # src with shape (input_window, batch_len, 1)
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.input_embedding(src) # linear transformation before positional embedding
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src,self.src_mask)#, self.src_mask)
        output = self.decoder(output)
        return output

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

# if window is 100 and prediction step is 1
# in -> [0..99]
# target -> [1..100]
'''
In fact, assuming that the number of samples is N, 
the length of the input sequence is m, and the backward prediction is k steps, 
then length of a block [input : 1 , 2 ... m  -> output : k , k+1....m+k ] 
should be (m+k) :  block_len, so to ensure that each block is complete, 
the end element of the last block should be the end element of the entire sequence, 
so the actual number of blocks is [N - block_len + 1] 
'''
def create_inout_sequences(input_data, input_window ,output_window):
    inout_seq = []
    L = len(input_data)
    block_num =  L - block_len + 1
    # total of [N - block_len + 1] blocks
    # where block_len = input_window + output_window

    for i in range( block_num ):
        train_seq = input_data[i : i + input_window]
        train_label = input_data[i + output_window : i + input_window + output_window]
        inout_seq.append((train_seq ,train_label))

    return torch.FloatTensor(np.array(inout_seq))

# Scale 따로

from sklearn.preprocessing import MinMaxScaler
scaler_train = MinMaxScaler(feature_range=(0,1))
scaler_test = MinMaxScaler(feature_range=(0,1))
scaler = MinMaxScaler()
def get_data(df):
    # construct a littel toy dataset
    time        = np.arange(0, 400, 0.1)    
    amplitude   = np.sin(time) + np.sin(time * 0.05) + \
                  np.sin(time * 0.12) * np.random.normal(-0.2, 0.2, len(time))
    
    df = df['TEMP'].values
    #loading weather data from a file
    #from pandas import read_csv
    #series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
    
    # looks like normalizing input values curtial for the model
    #amplitude = scaler.fit_transform(series.to_numpy().reshape(-1, 1)).reshape(-1)
    #amplitude = scaler.fit_transform(df.reshape(-1, 1)).reshape(-1)
    #sampels = int(len(time) * train_size) # use a parameter to control training size
    df = scaler.fit_transform(df.reshape(-1,1)).reshape(-1)
    train_size = int(len(df) * 0.8)
    train_data = df[:train_size]
    test_data = df[train_size:]
    # train_data = scaler_train.fit_transform(train_data.reshape(-1,1)).reshape(-1)
    # test_data = scaler_test.fit_transform(test_data.reshape(-1,1)).reshape(-1)

    # convert our train data into a pytorch train tensor
    #train_tensor = torch.FloatTensor(train_data).view(-1)

    train_sequence = create_inout_sequences( train_data,input_window ,output_window)
    '''
    train_sequence = train_sequence[:-output_window] # todo: fix hack? -> din't think this through, looks like the last n sequences are to short, so I just remove them. Hackety Hack..
    # looks like maybe solved
    '''
    #test_data = torch.FloatTensor(test_data).view(-1) 
    test_data = create_inout_sequences(test_data,input_window,output_window)
    '''
    test_data = test_data[:-output_window] # todo: fix hack?
    '''
    # shape with (block , sql_len , 2 )
    return train_sequence.to(device),test_data.to(device)


def get_batch(input_data, i , batch_size):

    # batch_len = min(batch_size, len(input_data) - 1 - i) #  # Now len-1 is not necessary
    batch_len = min(batch_size, len(input_data) - i)
    data = input_data[ i:i + batch_len ]
    input = torch.stack([item[0] for item in data]).view((input_window,batch_len,1))
    # ( seq_len, batch, 1 ) , 1 is feature size
    target = torch.stack([item[1] for item in data]).view((input_window,batch_len,1))
    return input, target

def train(train_data):
    model.train() # Turn on the train mode \o/
    total_loss = 0.
    start_time = time.time()

    for batch, i in enumerate(range(0, len(train_data), batch_size)):  # Now len-1 is not necessary
        # data and target are the same shape with (input_window,batch_len,1)
        data, targets = get_batch(train_data, i , batch_size)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.7)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_data) / batch_size / 5)
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.6f} | {:5.2f} ms | '
                  'loss {:5.5f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // batch_size, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()




def plot_and_loss(eval_model, data_source):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    with torch.no_grad():
        # for i in range(0, len(data_source) - 1):
        for i in range(len(data_source)):  # Now len-1 is not necessary
            data, target = get_batch(data_source, i , 1) # one-step forecast
            output = eval_model(data)            
            total_loss += criterion(output, target).item()
            test_result = torch.cat((test_result, output[-1].view(-1).cpu()), 0)
            truth = torch.cat((truth, target[-1].view(-1).cpu()), 0)
            
    #test_result = test_result.cpu().numpy() -> no need to detach stuff.. 
    len(test_result)
    # test_result = scaler_test.inverse_transform(test_result.reshape(-1,1)).reshape(-1)
    # truth = scaler_test.inverse_transform(truth.reshape(-1,1)).reshape(-1)
    test_result = scaler.inverse_transform(test_result.reshape(-1,1)).reshape(-1)
    truth = scaler.inverse_transform(truth.reshape(-1,1)).reshape(-1)
    print(test_result)
    pyplot.plot(test_result,color="red")
    pyplot.plot(truth,color="blue")
    pyplot.plot(test_result-truth,color="green")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.ylim([600,900])
    pyplot.show()
    pyplot.close()
    return test_result, truth, total_loss / i



# predict the next n steps based on the input data 
def predict_future(eval_model, data_source,steps):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    data, _ = get_batch(data_source , 0 , 1)
    with torch.no_grad():
        for i in range(0, steps):            
            output = eval_model(data[-input_window:])
            # (seq-len , batch-size , features-num)
            # input : [ m,m+1,...,m+n ] -> [m+1,...,m+n+1]
            data = torch.cat((data, output[-1:])) # [m,m+1,..., m+n+1]

    data = data.cpu().view(-1)
    #data = scaler_test.inverse_transform(data.reshape(-1,1)).reshape(-1)
    data = scaler.inverse_transform(data.reshape(-1,1)).reshape(-1)
    # I used this plot to visualize if the model pics up any long therm structure within the data.
    pyplot.plot(data,color="red")       
    pyplot.plot(data[:input_window],color="blue")    
    pyplot.grid(True, which='both')
    #pyplot.ylim([700,800])
    pyplot.axhline(y=0, color='k')
    #pyplot.savefig('graph/transformer-future%d.png'%steps)
    pyplot.show()
    pyplot.close()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    eval_batch_size = 256
    with torch.no_grad():
        # for i in range(0, len(data_source) - 1, eval_batch_size): # Now len-1 is not necessary
        for i in range(0, len(data_source), eval_batch_size):
            data, targets = get_batch(data_source, i,eval_batch_size)
            output = eval_model(data)            
            total_loss += len(data[0]) * criterion(output, targets).cpu().item()
    return total_loss / len(data_source)

from function_file.ML_functions import make_dataframe
_, df = make_dataframe(60,20)
train_data, val_data = get_data(df)
model = TransAm().to(device)

criterion = nn.MSELoss()
lr = 0.001
#optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.95)

best_val_loss = float("inf")
epochs = 100 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(train_data)
    if ( epoch % 20 == 0 ):
        test_result, truth, val_loss = plot_and_loss(model, val_data)
        #predict_future(model, val_data,5000)
    else:
        val_loss = evaluate(model, val_data)
   
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.5f} | valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    #if val_loss < best_val_loss:
    #    best_val_loss = val_loss
    #    best_model = model

    scheduler.step() 

#src = torch.rand(input_window, batch_size, 1) # (source sequence length,batch size,feature number) 
#out = model(src)
#
#print(out)
#print(out.shape)
# Out:
# | epoch   1 |   207/ 1038 batches | lr 0.001000 | 41.25 ms | loss 0.75821 | ppl     2.13
# | epoch   1 |   414/ 1038 batches | lr 0.001000 | 33.77 ms | loss 0.00145 | ppl     1.00
# | epoch   1 |   621/ 1038 batches | lr 0.001000 | 34.18 ms | loss 0.00072 | ppl     1.00
# | epoch   1 |   828/ 1038 batches | lr 0.001000 | 33.91 ms | loss 0.00035 | ppl     1.00
# | epoch   1 |  1035/ 1038 batches | lr 0.001000 | 33.79 ms | loss 0.00109 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 40.19s | valid loss 0.00550 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch   2 |   207/ 1038 batches | lr 0.000902 | 34.04 ms | loss 0.01041 | ppl     1.01
# | epoch   2 |   414/ 1038 batches | lr 0.000902 | 34.25 ms | loss 0.00073 | ppl     1.00
# | epoch   2 |   621/ 1038 batches | lr 0.000902 | 34.03 ms | loss 0.00040 | ppl     1.00
# | epoch   2 |   828/ 1038 batches | lr 0.000902 | 34.06 ms | loss 0.00029 | ppl     1.00
# | epoch   2 |  1035/ 1038 batches | lr 0.000902 | 34.15 ms | loss 0.00066 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 38.84s | valid loss 0.00507 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch   3 |   207/ 1038 batches | lr 0.000857 | 34.65 ms | loss 0.01231 | ppl     1.01
# | epoch   3 |   414/ 1038 batches | lr 0.000857 | 34.01 ms | loss 0.00060 | ppl     1.00
# | epoch   3 |   621/ 1038 batches | lr 0.000857 | 34.22 ms | loss 0.00033 | ppl     1.00
# | epoch   3 |   828/ 1038 batches | lr 0.000857 | 34.09 ms | loss 0.00060 | ppl     1.00
# | epoch   3 |  1035/ 1038 batches | lr 0.000857 | 34.40 ms | loss 0.00076 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 39.01s | valid loss 0.00422 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch   4 |   207/ 1038 batches | lr 0.000815 | 34.16 ms | loss 0.02017 | ppl     1.02
# | epoch   4 |   414/ 1038 batches | lr 0.000815 | 34.00 ms | loss 0.00073 | ppl     1.00
# | epoch   4 |   621/ 1038 batches | lr 0.000815 | 34.10 ms | loss 0.00055 | ppl     1.00
# | epoch   4 |   828/ 1038 batches | lr 0.000815 | 34.35 ms | loss 0.00077 | ppl     1.00
# | epoch   4 |  1035/ 1038 batches | lr 0.000815 | 33.98 ms | loss 0.00079 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 38.86s | valid loss 0.00393 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch   5 |   207/ 1038 batches | lr 0.000774 | 34.09 ms | loss 0.02108 | ppl     1.02
# | epoch   5 |   414/ 1038 batches | lr 0.000774 | 33.99 ms | loss 0.00078 | ppl     1.00
# | epoch   5 |   621/ 1038 batches | lr 0.000774 | 34.34 ms | loss 0.00068 | ppl     1.00
# | epoch   5 |   828/ 1038 batches | lr 0.000774 | 34.01 ms | loss 0.00075 | ppl     1.00
# | epoch   5 |  1035/ 1038 batches | lr 0.000774 | 33.92 ms | loss 0.00089 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 38.80s | valid loss 0.00398 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch   6 |   207/ 1038 batches | lr 0.000735 | 34.08 ms | loss 0.02339 | ppl     1.02
# | epoch   6 |   414/ 1038 batches | lr 0.000735 | 34.33 ms | loss 0.00064 | ppl     1.00
# | epoch   6 |   621/ 1038 batches | lr 0.000735 | 34.01 ms | loss 0.00083 | ppl     1.00
# | epoch   6 |   828/ 1038 batches | lr 0.000735 | 34.02 ms | loss 0.00083 | ppl     1.00
# | epoch   6 |  1035/ 1038 batches | lr 0.000735 | 34.10 ms | loss 0.00092 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 38.83s | valid loss 0.00406 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch   7 |   207/ 1038 batches | lr 0.000698 | 34.37 ms | loss 0.02482 | ppl     1.03
# | epoch   7 |   414/ 1038 batches | lr 0.000698 | 33.87 ms | loss 0.00057 | ppl     1.00
# | epoch   7 |   621/ 1038 batches | lr 0.000698 | 33.95 ms | loss 0.00075 | ppl     1.00
# | epoch   7 |   828/ 1038 batches | lr 0.000698 | 33.89 ms | loss 0.00059 | ppl     1.00
# | epoch   7 |  1035/ 1038 batches | lr 0.000698 | 34.33 ms | loss 0.00082 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 38.80s | valid loss 0.00660 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch   8 |   207/ 1038 batches | lr 0.000663 | 34.08 ms | loss 0.02203 | ppl     1.02
# | epoch   8 |   414/ 1038 batches | lr 0.000663 | 33.79 ms | loss 0.00057 | ppl     1.00
# | epoch   8 |   621/ 1038 batches | lr 0.000663 | 33.84 ms | loss 0.00069 | ppl     1.00
# | epoch   8 |   828/ 1038 batches | lr 0.000663 | 34.23 ms | loss 0.00069 | ppl     1.00
# | epoch   8 |  1035/ 1038 batches | lr 0.000663 | 33.87 ms | loss 0.00077 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 38.67s | valid loss 0.00414 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch   9 |   207/ 1038 batches | lr 0.000630 | 34.00 ms | loss 0.02968 | ppl     1.03
# | epoch   9 |   414/ 1038 batches | lr 0.000630 | 33.85 ms | loss 0.00061 | ppl     1.00
# | epoch   9 |   621/ 1038 batches | lr 0.000630 | 34.17 ms | loss 0.00062 | ppl     1.00
# | epoch   9 |   828/ 1038 batches | lr 0.000630 | 33.77 ms | loss 0.00071 | ppl     1.00
# | epoch   9 |  1035/ 1038 batches | lr 0.000630 | 34.08 ms | loss 0.00070 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 38.70s | valid loss 0.00409 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  10 |   207/ 1038 batches | lr 0.000599 | 34.07 ms | loss 0.03282 | ppl     1.03
# | epoch  10 |   414/ 1038 batches | lr 0.000599 | 34.33 ms | loss 0.00058 | ppl     1.00
# | epoch  10 |   621/ 1038 batches | lr 0.000599 | 33.84 ms | loss 0.00069 | ppl     1.00
# | epoch  10 |   828/ 1038 batches | lr 0.000599 | 33.95 ms | loss 0.00068 | ppl     1.00
# | epoch  10 |  1035/ 1038 batches | lr 0.000599 | 33.90 ms | loss 0.00073 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 38.78s | valid loss 0.00404 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  11 |   207/ 1038 batches | lr 0.000569 | 34.84 ms | loss 0.03623 | ppl     1.04
# | epoch  11 |   414/ 1038 batches | lr 0.000569 | 34.95 ms | loss 0.00072 | ppl     1.00
# | epoch  11 |   621/ 1038 batches | lr 0.000569 | 33.76 ms | loss 0.00062 | ppl     1.00
# | epoch  11 |   828/ 1038 batches | lr 0.000569 | 33.77 ms | loss 0.00067 | ppl     1.00
# | epoch  11 |  1035/ 1038 batches | lr 0.000569 | 34.09 ms | loss 0.00069 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 39.01s | valid loss 0.00422 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  12 |   207/ 1038 batches | lr 0.000540 | 34.03 ms | loss 0.03636 | ppl     1.04
# | epoch  12 |   414/ 1038 batches | lr 0.000540 | 33.68 ms | loss 0.00071 | ppl     1.00
# | epoch  12 |   621/ 1038 batches | lr 0.000540 | 33.44 ms | loss 0.00073 | ppl     1.00
# | epoch  12 |   828/ 1038 batches | lr 0.000540 | 34.09 ms | loss 0.00097 | ppl     1.00
# | epoch  12 |  1035/ 1038 batches | lr 0.000540 | 33.60 ms | loss 0.00068 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 38.45s | valid loss 0.00430 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  13 |   207/ 1038 batches | lr 0.000513 | 34.09 ms | loss 0.03852 | ppl     1.04
# | epoch  13 |   414/ 1038 batches | lr 0.000513 | 33.68 ms | loss 0.00072 | ppl     1.00
# | epoch  13 |   621/ 1038 batches | lr 0.000513 | 34.03 ms | loss 0.00073 | ppl     1.00
# | epoch  13 |   828/ 1038 batches | lr 0.000513 | 33.83 ms | loss 0.00110 | ppl     1.00
# | epoch  13 |  1035/ 1038 batches | lr 0.000513 | 34.17 ms | loss 0.00065 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 38.70s | valid loss 0.00545 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  14 |   207/ 1038 batches | lr 0.000488 | 34.08 ms | loss 0.04118 | ppl     1.04
# | epoch  14 |   414/ 1038 batches | lr 0.000488 | 33.75 ms | loss 0.00071 | ppl     1.00
# | epoch  14 |   621/ 1038 batches | lr 0.000488 | 33.59 ms | loss 0.00073 | ppl     1.00
# | epoch  14 |   828/ 1038 batches | lr 0.000488 | 33.45 ms | loss 0.00088 | ppl     1.00
# | epoch  14 |  1035/ 1038 batches | lr 0.000488 | 33.52 ms | loss 0.00063 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 38.38s | valid loss 0.00584 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  15 |   207/ 1038 batches | lr 0.000463 | 34.56 ms | loss 0.04070 | ppl     1.04
# | epoch  15 |   414/ 1038 batches | lr 0.000463 | 33.75 ms | loss 0.00070 | ppl     1.00
# | epoch  15 |   621/ 1038 batches | lr 0.000463 | 33.77 ms | loss 0.00074 | ppl     1.00
# | epoch  15 |   828/ 1038 batches | lr 0.000463 | 33.85 ms | loss 0.00109 | ppl     1.00
# | epoch  15 |  1035/ 1038 batches | lr 0.000463 | 34.32 ms | loss 0.00068 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 38.79s | valid loss 0.00660 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  16 |   207/ 1038 batches | lr 0.000440 | 34.00 ms | loss 0.04043 | ppl     1.04
# | epoch  16 |   414/ 1038 batches | lr 0.000440 | 33.85 ms | loss 0.00068 | ppl     1.00
# | epoch  16 |   621/ 1038 batches | lr 0.000440 | 34.08 ms | loss 0.00070 | ppl     1.00
# | epoch  16 |   828/ 1038 batches | lr 0.000440 | 34.32 ms | loss 0.00070 | ppl     1.00
# | epoch  16 |  1035/ 1038 batches | lr 0.000440 | 33.87 ms | loss 0.00060 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 38.75s | valid loss 0.00552 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  17 |   207/ 1038 batches | lr 0.000418 | 33.99 ms | loss 0.03909 | ppl     1.04
# | epoch  17 |   414/ 1038 batches | lr 0.000418 | 33.92 ms | loss 0.00069 | ppl     1.00
# | epoch  17 |   621/ 1038 batches | lr 0.000418 | 34.32 ms | loss 0.00073 | ppl     1.00
# | epoch  17 |   828/ 1038 batches | lr 0.000418 | 33.77 ms | loss 0.00099 | ppl     1.00
# | epoch  17 |  1035/ 1038 batches | lr 0.000418 | 33.85 ms | loss 0.00062 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 38.70s | valid loss 0.00684 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  18 |   207/ 1038 batches | lr 0.000397 | 33.93 ms | loss 0.03730 | ppl     1.04
# | epoch  18 |   414/ 1038 batches | lr 0.000397 | 34.27 ms | loss 0.00069 | ppl     1.00
# | epoch  18 |   621/ 1038 batches | lr 0.000397 | 33.90 ms | loss 0.00071 | ppl     1.00
# | epoch  18 |   828/ 1038 batches | lr 0.000397 | 33.93 ms | loss 0.00071 | ppl     1.00
# | epoch  18 |  1035/ 1038 batches | lr 0.000397 | 33.86 ms | loss 0.00058 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 38.72s | valid loss 0.00557 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  19 |   207/ 1038 batches | lr 0.000377 | 34.41 ms | loss 0.03336 | ppl     1.03
# | epoch  19 |   414/ 1038 batches | lr 0.000377 | 33.85 ms | loss 0.00068 | ppl     1.00
# | epoch  19 |   621/ 1038 batches | lr 0.000377 | 33.62 ms | loss 0.00067 | ppl     1.00
# | epoch  19 |   828/ 1038 batches | lr 0.000377 | 33.77 ms | loss 0.00064 | ppl     1.00
# | epoch  19 |  1035/ 1038 batches | lr 0.000377 | 34.18 ms | loss 0.00057 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 38.70s | valid loss 0.00515 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  20 |   207/ 1038 batches | lr 0.000358 | 33.93 ms | loss 0.03150 | ppl     1.03
# | epoch  20 |   414/ 1038 batches | lr 0.000358 | 33.84 ms | loss 0.00068 | ppl     1.00
# | epoch  20 |   621/ 1038 batches | lr 0.000358 | 34.17 ms | loss 0.00055 | ppl     1.00
# | epoch  20 |   828/ 1038 batches | lr 0.000358 | 33.76 ms | loss 0.00055 | ppl     1.00
# | epoch  20 |  1035/ 1038 batches | lr 0.000358 | 33.77 ms | loss 0.00050 | ppl     1.00
# [761.1645018  761.16281841 761.16427225 ... 772.12669958 772.12639351
#  772.12868903]
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 196.66s | valid loss 0.00409 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  21 |   207/ 1038 batches | lr 0.000341 | 34.00 ms | loss 0.02530 | ppl     1.03
# | epoch  21 |   414/ 1038 batches | lr 0.000341 | 33.85 ms | loss 0.00066 | ppl     1.00
# | epoch  21 |   621/ 1038 batches | lr 0.000341 | 33.53 ms | loss 0.00045 | ppl     1.00
# | epoch  21 |   828/ 1038 batches | lr 0.000341 | 33.59 ms | loss 0.00067 | ppl     1.00
# | epoch  21 |  1035/ 1038 batches | lr 0.000341 | 33.44 ms | loss 0.00050 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 38.39s | valid loss 0.00389 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  22 |   207/ 1038 batches | lr 0.000324 | 33.99 ms | loss 0.02026 | ppl     1.02
# | epoch  22 |   414/ 1038 batches | lr 0.000324 | 33.54 ms | loss 0.00059 | ppl     1.00
# | epoch  22 |   621/ 1038 batches | lr 0.000324 | 33.65 ms | loss 0.00025 | ppl     1.00
# | epoch  22 |   828/ 1038 batches | lr 0.000324 | 33.56 ms | loss 0.00036 | ppl     1.00
# | epoch  22 |  1035/ 1038 batches | lr 0.000324 | 33.93 ms | loss 0.00046 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 38.43s | valid loss 0.00238 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  23 |   207/ 1038 batches | lr 0.000307 | 33.75 ms | loss 0.00845 | ppl     1.01
# | epoch  23 |   414/ 1038 batches | lr 0.000307 | 33.55 ms | loss 0.00037 | ppl     1.00
# | epoch  23 |   621/ 1038 batches | lr 0.000307 | 33.66 ms | loss 0.00012 | ppl     1.00
# | epoch  23 |   828/ 1038 batches | lr 0.000307 | 33.92 ms | loss 0.00030 | ppl     1.00
# | epoch  23 |  1035/ 1038 batches | lr 0.000307 | 33.62 ms | loss 0.00041 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 38.38s | valid loss 0.00222 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  24 |   207/ 1038 batches | lr 0.000292 | 33.79 ms | loss 0.00338 | ppl     1.00
# | epoch  24 |   414/ 1038 batches | lr 0.000292 | 33.60 ms | loss 0.00018 | ppl     1.00
# | epoch  24 |   621/ 1038 batches | lr 0.000292 | 33.99 ms | loss 0.00013 | ppl     1.00
# | epoch  24 |   828/ 1038 batches | lr 0.000292 | 33.61 ms | loss 0.00020 | ppl     1.00
# | epoch  24 |  1035/ 1038 batches | lr 0.000292 | 33.53 ms | loss 0.00035 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 38.42s | valid loss 0.00208 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  25 |   207/ 1038 batches | lr 0.000277 | 33.75 ms | loss 0.00194 | ppl     1.00
# | epoch  25 |   414/ 1038 batches | lr 0.000277 | 34.01 ms | loss 0.00012 | ppl     1.00
# | epoch  25 |   621/ 1038 batches | lr 0.000277 | 33.63 ms | loss 0.00009 | ppl     1.00
# | epoch  25 |   828/ 1038 batches | lr 0.000277 | 33.65 ms | loss 0.00019 | ppl     1.00
# | epoch  25 |  1035/ 1038 batches | lr 0.000277 | 33.54 ms | loss 0.00034 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 38.43s | valid loss 0.00205 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  26 |   207/ 1038 batches | lr 0.000264 | 34.18 ms | loss 0.00138 | ppl     1.00
# | epoch  26 |   414/ 1038 batches | lr 0.000264 | 33.56 ms | loss 0.00010 | ppl     1.00
# | epoch  26 |   621/ 1038 batches | lr 0.000264 | 33.57 ms | loss 0.00008 | ppl     1.00
# | epoch  26 |   828/ 1038 batches | lr 0.000264 | 33.58 ms | loss 0.00017 | ppl     1.00
# | epoch  26 |  1035/ 1038 batches | lr 0.000264 | 33.93 ms | loss 0.00033 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 38.48s | valid loss 0.00201 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  27 |   207/ 1038 batches | lr 0.000250 | 33.62 ms | loss 0.00097 | ppl     1.00
# | epoch  27 |   414/ 1038 batches | lr 0.000250 | 33.67 ms | loss 0.00010 | ppl     1.00
# | epoch  27 |   621/ 1038 batches | lr 0.000250 | 33.44 ms | loss 0.00007 | ppl     1.00
# | epoch  27 |   828/ 1038 batches | lr 0.000250 | 34.02 ms | loss 0.00016 | ppl     1.00
# | epoch  27 |  1035/ 1038 batches | lr 0.000250 | 33.70 ms | loss 0.00031 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 38.41s | valid loss 0.00196 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  28 |   207/ 1038 batches | lr 0.000238 | 33.77 ms | loss 0.00076 | ppl     1.00
# | epoch  28 |   414/ 1038 batches | lr 0.000238 | 33.54 ms | loss 0.00008 | ppl     1.00
# | epoch  28 |   621/ 1038 batches | lr 0.000238 | 33.84 ms | loss 0.00006 | ppl     1.00
# | epoch  28 |   828/ 1038 batches | lr 0.000238 | 33.62 ms | loss 0.00014 | ppl     1.00
# | epoch  28 |  1035/ 1038 batches | lr 0.000238 | 33.60 ms | loss 0.00029 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 38.37s | valid loss 0.00198 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  29 |   207/ 1038 batches | lr 0.000226 | 33.62 ms | loss 0.00060 | ppl     1.00
# | epoch  29 |   414/ 1038 batches | lr 0.000226 | 33.91 ms | loss 0.00007 | ppl     1.00
# | epoch  29 |   621/ 1038 batches | lr 0.000226 | 33.55 ms | loss 0.00005 | ppl     1.00
# | epoch  29 |   828/ 1038 batches | lr 0.000226 | 33.67 ms | loss 0.00013 | ppl     1.00
# | epoch  29 |  1035/ 1038 batches | lr 0.000226 | 33.63 ms | loss 0.00028 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 38.37s | valid loss 0.00203 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  30 |   207/ 1038 batches | lr 0.000215 | 34.24 ms | loss 0.00051 | ppl     1.00
# | epoch  30 |   414/ 1038 batches | lr 0.000215 | 33.61 ms | loss 0.00006 | ppl     1.00
# | epoch  30 |   621/ 1038 batches | lr 0.000215 | 33.59 ms | loss 0.00005 | ppl     1.00
# | epoch  30 |   828/ 1038 batches | lr 0.000215 | 33.62 ms | loss 0.00013 | ppl     1.00
# | epoch  30 |  1035/ 1038 batches | lr 0.000215 | 34.00 ms | loss 0.00026 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 38.53s | valid loss 0.00198 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  31 |   207/ 1038 batches | lr 0.000204 | 33.76 ms | loss 0.00049 | ppl     1.00
# | epoch  31 |   414/ 1038 batches | lr 0.000204 | 33.67 ms | loss 0.00005 | ppl     1.00
# | epoch  31 |   621/ 1038 batches | lr 0.000204 | 33.62 ms | loss 0.00005 | ppl     1.00
# | epoch  31 |   828/ 1038 batches | lr 0.000204 | 34.06 ms | loss 0.00012 | ppl     1.00
# | epoch  31 |  1035/ 1038 batches | lr 0.000204 | 33.67 ms | loss 0.00026 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 38.43s | valid loss 0.00201 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  32 |   207/ 1038 batches | lr 0.000194 | 33.83 ms | loss 0.00051 | ppl     1.00
# | epoch  32 |   414/ 1038 batches | lr 0.000194 | 33.51 ms | loss 0.00005 | ppl     1.00
# | epoch  32 |   621/ 1038 batches | lr 0.000194 | 34.00 ms | loss 0.00005 | ppl     1.00
# | epoch  32 |   828/ 1038 batches | lr 0.000194 | 33.89 ms | loss 0.00011 | ppl     1.00
# | epoch  32 |  1035/ 1038 batches | lr 0.000194 | 33.80 ms | loss 0.00023 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 38.55s | valid loss 0.00194 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  33 |   207/ 1038 batches | lr 0.000184 | 33.87 ms | loss 0.00043 | ppl     1.00
# | epoch  33 |   414/ 1038 batches | lr 0.000184 | 34.12 ms | loss 0.00005 | ppl     1.00
# | epoch  33 |   621/ 1038 batches | lr 0.000184 | 33.67 ms | loss 0.00005 | ppl     1.00
# | epoch  33 |   828/ 1038 batches | lr 0.000184 | 33.84 ms | loss 0.00010 | ppl     1.00
# | epoch  33 |  1035/ 1038 batches | lr 0.000184 | 33.84 ms | loss 0.00022 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 38.61s | valid loss 0.00190 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  34 |   207/ 1038 batches | lr 0.000175 | 34.33 ms | loss 0.00037 | ppl     1.00
# | epoch  34 |   414/ 1038 batches | lr 0.000175 | 36.44 ms | loss 0.00005 | ppl     1.00
# | epoch  34 |   621/ 1038 batches | lr 0.000175 | 33.75 ms | loss 0.00005 | ppl     1.00
# | epoch  34 |   828/ 1038 batches | lr 0.000175 | 33.71 ms | loss 0.00010 | ppl     1.00
# | epoch  34 |  1035/ 1038 batches | lr 0.000175 | 34.07 ms | loss 0.00020 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 39.22s | valid loss 0.00182 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  35 |   207/ 1038 batches | lr 0.000166 | 33.92 ms | loss 0.00036 | ppl     1.00
# | epoch  35 |   414/ 1038 batches | lr 0.000166 | 33.56 ms | loss 0.00004 | ppl     1.00
# | epoch  35 |   621/ 1038 batches | lr 0.000166 | 33.74 ms | loss 0.00004 | ppl     1.00
# | epoch  35 |   828/ 1038 batches | lr 0.000166 | 34.17 ms | loss 0.00009 | ppl     1.00
# | epoch  35 |  1035/ 1038 batches | lr 0.000166 | 33.83 ms | loss 0.00019 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 38.55s | valid loss 0.00183 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  36 |   207/ 1038 batches | lr 0.000158 | 33.84 ms | loss 0.00032 | ppl     1.00
# | epoch  36 |   414/ 1038 batches | lr 0.000158 | 33.76 ms | loss 0.00004 | ppl     1.00
# | epoch  36 |   621/ 1038 batches | lr 0.000158 | 34.27 ms | loss 0.00004 | ppl     1.00
# | epoch  36 |   828/ 1038 batches | lr 0.000158 | 33.91 ms | loss 0.00009 | ppl     1.00
# | epoch  36 |  1035/ 1038 batches | lr 0.000158 | 33.91 ms | loss 0.00017 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 38.65s | valid loss 0.00177 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  37 |   207/ 1038 batches | lr 0.000150 | 33.92 ms | loss 0.00031 | ppl     1.00
# | epoch  37 |   414/ 1038 batches | lr 0.000150 | 34.01 ms | loss 0.00004 | ppl     1.00
# | epoch  37 |   621/ 1038 batches | lr 0.000150 | 33.72 ms | loss 0.00004 | ppl     1.00
# | epoch  37 |   828/ 1038 batches | lr 0.000150 | 33.80 ms | loss 0.00008 | ppl     1.00
# | epoch  37 |  1035/ 1038 batches | lr 0.000150 | 33.76 ms | loss 0.00017 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 38.56s | valid loss 0.00177 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  38 |   207/ 1038 batches | lr 0.000142 | 34.26 ms | loss 0.00029 | ppl     1.00
# | epoch  38 |   414/ 1038 batches | lr 0.000142 | 33.68 ms | loss 0.00004 | ppl     1.00
# | epoch  38 |   621/ 1038 batches | lr 0.000142 | 33.76 ms | loss 0.00004 | ppl     1.00
# | epoch  38 |   828/ 1038 batches | lr 0.000142 | 33.61 ms | loss 0.00008 | ppl     1.00
# | epoch  38 |  1035/ 1038 batches | lr 0.000142 | 34.17 ms | loss 0.00016 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 38.62s | valid loss 0.00167 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  39 |   207/ 1038 batches | lr 0.000135 | 33.86 ms | loss 0.00027 | ppl     1.00
# | epoch  39 |   414/ 1038 batches | lr 0.000135 | 33.74 ms | loss 0.00004 | ppl     1.00
# | epoch  39 |   621/ 1038 batches | lr 0.000135 | 33.68 ms | loss 0.00004 | ppl     1.00
# | epoch  39 |   828/ 1038 batches | lr 0.000135 | 34.16 ms | loss 0.00008 | ppl     1.00
# | epoch  39 |  1035/ 1038 batches | lr 0.000135 | 33.77 ms | loss 0.00015 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 38.59s | valid loss 0.00161 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  40 |   207/ 1038 batches | lr 0.000129 | 33.83 ms | loss 0.00025 | ppl     1.00
# | epoch  40 |   414/ 1038 batches | lr 0.000129 | 33.92 ms | loss 0.00004 | ppl     1.00
# | epoch  40 |   621/ 1038 batches | lr 0.000129 | 34.01 ms | loss 0.00004 | ppl     1.00
# | epoch  40 |   828/ 1038 batches | lr 0.000129 | 33.77 ms | loss 0.00007 | ppl     1.00
# | epoch  40 |  1035/ 1038 batches | lr 0.000129 | 33.84 ms | loss 0.00015 | ppl     1.00
# [770.53999521 770.53727884 770.55254408 ... 809.27126017 809.27106888
#  809.27045674]
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 199.51s | valid loss 0.00160 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  41 |   207/ 1038 batches | lr 0.000122 | 33.92 ms | loss 0.00025 | ppl     1.00
# | epoch  41 |   414/ 1038 batches | lr 0.000122 | 33.86 ms | loss 0.00004 | ppl     1.00
# | epoch  41 |   621/ 1038 batches | lr 0.000122 | 33.35 ms | loss 0.00003 | ppl     1.00
# | epoch  41 |   828/ 1038 batches | lr 0.000122 | 33.53 ms | loss 0.00007 | ppl     1.00
# | epoch  41 |  1035/ 1038 batches | lr 0.000122 | 33.77 ms | loss 0.00014 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 38.40s | valid loss 0.00159 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  42 |   207/ 1038 batches | lr 0.000116 | 34.26 ms | loss 0.00023 | ppl     1.00
# | epoch  42 |   414/ 1038 batches | lr 0.000116 | 33.68 ms | loss 0.00003 | ppl     1.00
# | epoch  42 |   621/ 1038 batches | lr 0.000116 | 33.67 ms | loss 0.00003 | ppl     1.00
# | epoch  42 |   828/ 1038 batches | lr 0.000116 | 33.68 ms | loss 0.00007 | ppl     1.00
# | epoch  42 |  1035/ 1038 batches | lr 0.000116 | 34.18 ms | loss 0.00014 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 38.60s | valid loss 0.00159 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  43 |   207/ 1038 batches | lr 0.000110 | 33.83 ms | loss 0.00021 | ppl     1.00
# | epoch  43 |   414/ 1038 batches | lr 0.000110 | 33.68 ms | loss 0.00003 | ppl     1.00
# | epoch  43 |   621/ 1038 batches | lr 0.000110 | 33.60 ms | loss 0.00003 | ppl     1.00
# | epoch  43 |   828/ 1038 batches | lr 0.000110 | 34.11 ms | loss 0.00006 | ppl     1.00
# | epoch  43 |  1035/ 1038 batches | lr 0.000110 | 33.69 ms | loss 0.00013 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 38.50s | valid loss 0.00154 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  44 |   207/ 1038 batches | lr 0.000105 | 33.84 ms | loss 0.00020 | ppl     1.00
# | epoch  44 |   414/ 1038 batches | lr 0.000105 | 33.68 ms | loss 0.00003 | ppl     1.00
# | epoch  44 |   621/ 1038 batches | lr 0.000105 | 34.20 ms | loss 0.00003 | ppl     1.00
# | epoch  44 |   828/ 1038 batches | lr 0.000105 | 33.73 ms | loss 0.00006 | ppl     1.00
# | epoch  44 |  1035/ 1038 batches | lr 0.000105 | 33.69 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 38.53s | valid loss 0.00149 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  45 |   207/ 1038 batches | lr 0.000099 | 33.69 ms | loss 0.00019 | ppl     1.00
# | epoch  45 |   414/ 1038 batches | lr 0.000099 | 33.94 ms | loss 0.00003 | ppl     1.00
# | epoch  45 |   621/ 1038 batches | lr 0.000099 | 33.60 ms | loss 0.00003 | ppl     1.00
# | epoch  45 |   828/ 1038 batches | lr 0.000099 | 33.77 ms | loss 0.00006 | ppl     1.00
# | epoch  45 |  1035/ 1038 batches | lr 0.000099 | 33.75 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 38.45s | valid loss 0.00146 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  46 |   207/ 1038 batches | lr 0.000094 | 34.26 ms | loss 0.00018 | ppl     1.00
# | epoch  46 |   414/ 1038 batches | lr 0.000094 | 33.77 ms | loss 0.00003 | ppl     1.00
# | epoch  46 |   621/ 1038 batches | lr 0.000094 | 33.67 ms | loss 0.00003 | ppl     1.00
# | epoch  46 |   828/ 1038 batches | lr 0.000094 | 33.77 ms | loss 0.00006 | ppl     1.00
# | epoch  46 |  1035/ 1038 batches | lr 0.000094 | 34.13 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 38.62s | valid loss 0.00143 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  47 |   207/ 1038 batches | lr 0.000090 | 34.23 ms | loss 0.00018 | ppl     1.00
# | epoch  47 |   414/ 1038 batches | lr 0.000090 | 33.71 ms | loss 0.00003 | ppl     1.00
# | epoch  47 |   621/ 1038 batches | lr 0.000090 | 34.18 ms | loss 0.00002 | ppl     1.00
# | epoch  47 |   828/ 1038 batches | lr 0.000090 | 33.83 ms | loss 0.00005 | ppl     1.00
# | epoch  47 |  1035/ 1038 batches | lr 0.000090 | 34.02 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 38.73s | valid loss 0.00140 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  48 |   207/ 1038 batches | lr 0.000085 | 34.08 ms | loss 0.00017 | ppl     1.00
# | epoch  48 |   414/ 1038 batches | lr 0.000085 | 33.85 ms | loss 0.00003 | ppl     1.00
# | epoch  48 |   621/ 1038 batches | lr 0.000085 | 34.25 ms | loss 0.00002 | ppl     1.00
# | epoch  48 |   828/ 1038 batches | lr 0.000085 | 34.10 ms | loss 0.00005 | ppl     1.00
# | epoch  48 |  1035/ 1038 batches | lr 0.000085 | 33.95 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 38.82s | valid loss 0.00137 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  49 |   207/ 1038 batches | lr 0.000081 | 34.39 ms | loss 0.00016 | ppl     1.00
# | epoch  49 |   414/ 1038 batches | lr 0.000081 | 33.93 ms | loss 0.00003 | ppl     1.00
# | epoch  49 |   621/ 1038 batches | lr 0.000081 | 33.82 ms | loss 0.00002 | ppl     1.00
# | epoch  49 |   828/ 1038 batches | lr 0.000081 | 33.91 ms | loss 0.00005 | ppl     1.00
# | epoch  49 |  1035/ 1038 batches | lr 0.000081 | 34.29 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 38.83s | valid loss 0.00134 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  50 |   207/ 1038 batches | lr 0.000077 | 34.09 ms | loss 0.00016 | ppl     1.00
# | epoch  50 |   414/ 1038 batches | lr 0.000077 | 34.02 ms | loss 0.00003 | ppl     1.00
# | epoch  50 |   621/ 1038 batches | lr 0.000077 | 33.89 ms | loss 0.00002 | ppl     1.00
# | epoch  50 |   828/ 1038 batches | lr 0.000077 | 34.25 ms | loss 0.00005 | ppl     1.00
# | epoch  50 |  1035/ 1038 batches | lr 0.000077 | 33.98 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 38.86s | valid loss 0.00132 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  51 |   207/ 1038 batches | lr 0.000073 | 34.77 ms | loss 0.00015 | ppl     1.00
# | epoch  51 |   414/ 1038 batches | lr 0.000073 | 33.88 ms | loss 0.00003 | ppl     1.00
# | epoch  51 |   621/ 1038 batches | lr 0.000073 | 34.68 ms | loss 0.00002 | ppl     1.00
# | epoch  51 |   828/ 1038 batches | lr 0.000073 | 34.43 ms | loss 0.00005 | ppl     1.00
# | epoch  51 |  1035/ 1038 batches | lr 0.000073 | 34.54 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 39.20s | valid loss 0.00130 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  52 |   207/ 1038 batches | lr 0.000069 | 34.03 ms | loss 0.00015 | ppl     1.00
# | epoch  52 |   414/ 1038 batches | lr 0.000069 | 34.27 ms | loss 0.00003 | ppl     1.00
# | epoch  52 |   621/ 1038 batches | lr 0.000069 | 34.05 ms | loss 0.00002 | ppl     1.00
# | epoch  52 |   828/ 1038 batches | lr 0.000069 | 34.32 ms | loss 0.00005 | ppl     1.00
# | epoch  52 |  1035/ 1038 batches | lr 0.000069 | 34.31 ms | loss 0.00009 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 38.99s | valid loss 0.00128 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  53 |   207/ 1038 batches | lr 0.000066 | 34.40 ms | loss 0.00015 | ppl     1.00
# | epoch  53 |   414/ 1038 batches | lr 0.000066 | 33.75 ms | loss 0.00003 | ppl     1.00
# | epoch  53 |   621/ 1038 batches | lr 0.000066 | 33.94 ms | loss 0.00002 | ppl     1.00
# | epoch  53 |   828/ 1038 batches | lr 0.000066 | 33.92 ms | loss 0.00005 | ppl     1.00
# | epoch  53 |  1035/ 1038 batches | lr 0.000066 | 34.40 ms | loss 0.00009 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 38.86s | valid loss 0.00126 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  54 |   207/ 1038 batches | lr 0.000063 | 34.19 ms | loss 0.00014 | ppl     1.00
# | epoch  54 |   414/ 1038 batches | lr 0.000063 | 33.95 ms | loss 0.00003 | ppl     1.00
# | epoch  54 |   621/ 1038 batches | lr 0.000063 | 34.13 ms | loss 0.00002 | ppl     1.00
# | epoch  54 |   828/ 1038 batches | lr 0.000063 | 34.48 ms | loss 0.00004 | ppl     1.00
# | epoch  54 |  1035/ 1038 batches | lr 0.000063 | 33.93 ms | loss 0.00009 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 38.88s | valid loss 0.00124 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  55 |   207/ 1038 batches | lr 0.000060 | 34.04 ms | loss 0.00014 | ppl     1.00
# | epoch  55 |   414/ 1038 batches | lr 0.000060 | 33.94 ms | loss 0.00003 | ppl     1.00
# | epoch  55 |   621/ 1038 batches | lr 0.000060 | 34.41 ms | loss 0.00002 | ppl     1.00
# | epoch  55 |   828/ 1038 batches | lr 0.000060 | 34.08 ms | loss 0.00004 | ppl     1.00
# | epoch  55 |  1035/ 1038 batches | lr 0.000060 | 34.05 ms | loss 0.00008 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 38.86s | valid loss 0.00122 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  56 |   207/ 1038 batches | lr 0.000057 | 34.08 ms | loss 0.00014 | ppl     1.00
# | epoch  56 |   414/ 1038 batches | lr 0.000057 | 34.38 ms | loss 0.00003 | ppl     1.00
# | epoch  56 |   621/ 1038 batches | lr 0.000057 | 34.11 ms | loss 0.00002 | ppl     1.00
# | epoch  56 |   828/ 1038 batches | lr 0.000057 | 34.18 ms | loss 0.00004 | ppl     1.00
# | epoch  56 |  1035/ 1038 batches | lr 0.000057 | 34.09 ms | loss 0.00008 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 38.90s | valid loss 0.00120 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  57 |   207/ 1038 batches | lr 0.000054 | 34.50 ms | loss 0.00013 | ppl     1.00
# | epoch  57 |   414/ 1038 batches | lr 0.000054 | 34.10 ms | loss 0.00003 | ppl     1.00
# | epoch  57 |   621/ 1038 batches | lr 0.000054 | 33.97 ms | loss 0.00002 | ppl     1.00
# | epoch  57 |   828/ 1038 batches | lr 0.000054 | 34.17 ms | loss 0.00004 | ppl     1.00
# | epoch  57 |  1035/ 1038 batches | lr 0.000054 | 34.49 ms | loss 0.00008 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 39.04s | valid loss 0.00119 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  58 |   207/ 1038 batches | lr 0.000051 | 34.34 ms | loss 0.00013 | ppl     1.00
# | epoch  58 |   414/ 1038 batches | lr 0.000051 | 34.17 ms | loss 0.00003 | ppl     1.00
# | epoch  58 |   621/ 1038 batches | lr 0.000051 | 34.16 ms | loss 0.00002 | ppl     1.00
# | epoch  58 |   828/ 1038 batches | lr 0.000051 | 34.48 ms | loss 0.00004 | ppl     1.00
# | epoch  58 |  1035/ 1038 batches | lr 0.000051 | 34.23 ms | loss 0.00008 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time: 39.03s | valid loss 0.00118 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  59 |   207/ 1038 batches | lr 0.000048 | 34.32 ms | loss 0.00012 | ppl     1.00
# | epoch  59 |   414/ 1038 batches | lr 0.000048 | 34.14 ms | loss 0.00003 | ppl     1.00
# | epoch  59 |   621/ 1038 batches | lr 0.000048 | 34.53 ms | loss 0.00002 | ppl     1.00
# | epoch  59 |   828/ 1038 batches | lr 0.000048 | 34.09 ms | loss 0.00004 | ppl     1.00
# | epoch  59 |  1035/ 1038 batches | lr 0.000048 | 34.54 ms | loss 0.00007 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time: 39.07s | valid loss 0.00117 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  60 |   207/ 1038 batches | lr 0.000046 | 34.25 ms | loss 0.00012 | ppl     1.00
# | epoch  60 |   414/ 1038 batches | lr 0.000046 | 34.40 ms | loss 0.00003 | ppl     1.00
# | epoch  60 |   621/ 1038 batches | lr 0.000046 | 33.86 ms | loss 0.00002 | ppl     1.00
# | epoch  60 |   828/ 1038 batches | lr 0.000046 | 34.06 ms | loss 0.00004 | ppl     1.00
# | epoch  60 |  1035/ 1038 batches | lr 0.000046 | 34.06 ms | loss 0.00007 | ppl     1.00
# [776.88753959 776.87277172 776.87797491 ... 829.63929054 829.63446994
#  829.62008466]
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time: 205.27s | valid loss 0.00116 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  61 |   207/ 1038 batches | lr 0.000044 | 34.51 ms | loss 0.00012 | ppl     1.00
# | epoch  61 |   414/ 1038 batches | lr 0.000044 | 33.56 ms | loss 0.00003 | ppl     1.00
# | epoch  61 |   621/ 1038 batches | lr 0.000044 | 33.48 ms | loss 0.00002 | ppl     1.00
# | epoch  61 |   828/ 1038 batches | lr 0.000044 | 33.61 ms | loss 0.00004 | ppl     1.00
# | epoch  61 |  1035/ 1038 batches | lr 0.000044 | 34.00 ms | loss 0.00007 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time: 38.53s | valid loss 0.00115 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  62 |   207/ 1038 batches | lr 0.000042 | 33.61 ms | loss 0.00012 | ppl     1.00
# | epoch  62 |   414/ 1038 batches | lr 0.000042 | 33.43 ms | loss 0.00003 | ppl     1.00
# | epoch  62 |   621/ 1038 batches | lr 0.000042 | 33.59 ms | loss 0.00002 | ppl     1.00
# | epoch  62 |   828/ 1038 batches | lr 0.000042 | 33.90 ms | loss 0.00004 | ppl     1.00
# | epoch  62 |  1035/ 1038 batches | lr 0.000042 | 33.68 ms | loss 0.00007 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time: 38.37s | valid loss 0.00114 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  63 |   207/ 1038 batches | lr 0.000039 | 33.84 ms | loss 0.00011 | ppl     1.00
# | epoch  63 |   414/ 1038 batches | lr 0.000039 | 33.87 ms | loss 0.00003 | ppl     1.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Sejong\Desktop\hanhwa\model\transformer_singlestep_prediction_11_24.ipynb 셀 2 line 2
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=286'>287</a> for epoch in range(1, epochs + 1):
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=287'>288</a>     epoch_start_time = time.time()
# --> <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=288'>289</a>     train(train_data)
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=289'>290</a>     if ( epoch % 20 == 0 ):
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=290'>291</a>         test_result, truth, val_loss = plot_and_loss(model, val_data)
#
# c:\Users\Sejong\Desktop\hanhwa\model\transformer_singlestep_prediction_11_24.ipynb 셀 2 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=175'>176</a> output = model(data)
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=176'>177</a> loss = criterion(output, targets)
# --> <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=177'>178</a> loss.backward()
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=178'>179</a> torch.nn.utils.clip_grad_norm_(model.parameters(), 0.7)
#     <a href='vscode-notebook-cell:/c%3A/Users/Sejong/Desktop/hanhwa/model/transformer_singlestep_prediction_11_24.ipynb#W1sZmlsZQ%3D%3D?line=179'>180</a> optimizer.step()
#
# File c:\Users\Sejong\Desktop\hanhwa\hanhwa\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File c:\Users\Sejong\Desktop\hanhwa\hanhwa\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
print("r2 : ", r2_score(truth, test_result))
print("MAE : ", mean_absolute_error(truth, test_result))
print("RMSE : ", mean_squared_error(truth, test_result)**0.5)
# Out:
# r2 :  0.9920416676042212
# MAE :  2.651352262571854
# RMSE :  3.6040381436087134
