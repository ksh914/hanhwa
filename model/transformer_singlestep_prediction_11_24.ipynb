# %%
cd ..
# Out:
# c:\Users\Sejong\Desktop\hanhwa

# %%
import torch
import torch.nn as nn
import numpy as np
import time
import math
from matplotlib import pyplot
import warnings
warnings.filterwarnings('ignore')
torch.manual_seed(0)
np.random.seed(0)

# S is the source sequence length
# T is the target sequence length
# N is the batch size
# E is the feature number

#src = torch.rand((10, 32, 512)) # (S,N,E) 
#tgt = torch.rand((20, 32, 512)) # (T,N,E)
#out = transformer_model(src, tgt)

input_window = 20 # number of input steps
output_window = 1 # number of prediction steps, in this model its fixed to one
block_len = input_window + output_window # for one input-output pair
batch_size = 512
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_len=5000):
        super(PositionalEncoding, self).__init__()       
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(max_len, dtype=torch.float).unsqueeze(1)
        # div_term = torch.exp(
        #     torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model)
        # )
        div_term = 1 / (10000 ** ((2 * np.arange(d_model)) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term[0::2])
        pe[:, 1::2] = torch.cos(position * div_term[1::2])

        pe = pe.unsqueeze(0).transpose(0, 1) # [5000, 1, d_model],so need seq-len <= 5000
        #pe.requires_grad = False
        self.register_buffer('pe', pe)

    def forward(self, x):
        # print(self.pe[:x.size(0), :].repeat(1,x.shape[1],1).shape ,'---',x.shape)
        # dimension 1 maybe inequal batchsize
        return x + self.pe[:x.size(0), :].repeat(1,x.shape[1],1)
          

class TransAm(nn.Module):
    def __init__(self,feature_size=250,num_layers=1,dropout=0.1):
        super(TransAm, self).__init__()
        self.model_type = 'Transformer'
        self.input_embedding  = nn.Linear(1,feature_size)
        self.src_mask = None

        self.pos_encoder = PositionalEncoding(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=10, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src):
        # src with shape (input_window, batch_len, 1)
        if self.src_mask is None or self.src_mask.size(0) != len(src):
            device = src.device
            mask = self._generate_square_subsequent_mask(len(src)).to(device)
            self.src_mask = mask

        src = self.input_embedding(src) # linear transformation before positional embedding
        src = self.pos_encoder(src)
        output = self.transformer_encoder(src,self.src_mask)#, self.src_mask)
        output = self.decoder(output)
        return output

    def _generate_square_subsequent_mask(self, sz):
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        return mask

# if window is 100 and prediction step is 1
# in -> [0..99]
# target -> [1..100]
'''
In fact, assuming that the number of samples is N, 
the length of the input sequence is m, and the backward prediction is k steps, 
then length of a block [input : 1 , 2 ... m  -> output : k , k+1....m+k ] 
should be (m+k) :  block_len, so to ensure that each block is complete, 
the end element of the last block should be the end element of the entire sequence, 
so the actual number of blocks is [N - block_len + 1] 
'''
def create_inout_sequences(input_data, input_window ,output_window):
    inout_seq = []
    L = len(input_data)
    block_num =  L - block_len + 1
    # total of [N - block_len + 1] blocks
    # where block_len = input_window + output_window

    for i in range( block_num ):
        train_seq = input_data[i : i + input_window]
        train_label = input_data[i + output_window : i + input_window + output_window]
        inout_seq.append((train_seq ,train_label))

    return torch.FloatTensor(np.array(inout_seq))

# Scale 따로

from sklearn.preprocessing import MinMaxScaler
scaler_train = MinMaxScaler(feature_range=(0,1))
scaler_test = MinMaxScaler(feature_range=(0,1))

def get_data(df):
    # construct a littel toy dataset
    time        = np.arange(0, 400, 0.1)    
    amplitude   = np.sin(time) + np.sin(time * 0.05) + \
                  np.sin(time * 0.12) * np.random.normal(-0.2, 0.2, len(time))
    
    df = df['TEMP'].values
    #loading weather data from a file
    #from pandas import read_csv
    #series = read_csv('daily-min-temperatures.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
    
    # looks like normalizing input values curtial for the model
    #amplitude = scaler.fit_transform(series.to_numpy().reshape(-1, 1)).reshape(-1)
    #amplitude = scaler.fit_transform(df.reshape(-1, 1)).reshape(-1)
    train_size = int(len(df) * 0.8)
    #sampels = int(len(time) * train_size) # use a parameter to control training size
    samples = 2800
    train_data = df[:train_size]
    test_data = df[train_size:]
    train_data = scaler_train.fit_transform(train_data.reshape(-1,1)).reshape(-1)
    test_data = scaler_test.fit_transform(test_data.reshape(-1,1)).reshape(-1)

    # convert our train data into a pytorch train tensor
    #train_tensor = torch.FloatTensor(train_data).view(-1)

    train_sequence = create_inout_sequences( train_data,input_window ,output_window)
    '''
    train_sequence = train_sequence[:-output_window] # todo: fix hack? -> din't think this through, looks like the last n sequences are to short, so I just remove them. Hackety Hack..
    # looks like maybe solved
    '''
    #test_data = torch.FloatTensor(test_data).view(-1) 
    test_data = create_inout_sequences(test_data,input_window,output_window)
    '''
    test_data = test_data[:-output_window] # todo: fix hack?
    '''
    # shape with (block , sql_len , 2 )
    return train_sequence.to(device),test_data.to(device)


def get_batch(input_data, i , batch_size):

    # batch_len = min(batch_size, len(input_data) - 1 - i) #  # Now len-1 is not necessary
    batch_len = min(batch_size, len(input_data) - i)
    data = input_data[ i:i + batch_len ]
    input = torch.stack([item[0] for item in data]).view((input_window,batch_len,1))
    # ( seq_len, batch, 1 ) , 1 is feature size
    target = torch.stack([item[1] for item in data]).view((input_window,batch_len,1))
    return input, target

def train(train_data):
    model.train() # Turn on the train mode \o/
    total_loss = 0.
    start_time = time.time()

    for batch, i in enumerate(range(0, len(train_data), batch_size)):  # Now len-1 is not necessary
        # data and target are the same shape with (input_window,batch_len,1)
        data, targets = get_batch(train_data, i , batch_size)
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.7)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_data) / batch_size / 5)
        if batch % log_interval == 0 and batch > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time
            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.6f} | {:5.2f} ms | '
                  'loss {:5.5f} | ppl {:8.2f}'.format(
                    epoch, batch, len(train_data) // batch_size, scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss)))
            total_loss = 0
            start_time = time.time()




def plot_and_loss(eval_model, data_source):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    with torch.no_grad():
        # for i in range(0, len(data_source) - 1):
        for i in range(len(data_source)):  # Now len-1 is not necessary
            data, target = get_batch(data_source, i , 1) # one-step forecast
            output = eval_model(data)            
            total_loss += criterion(output, target).item()
            test_result = torch.cat((test_result, output[-1].view(-1).cpu()), 0)
            truth = torch.cat((truth, target[-1].view(-1).cpu()), 0)
            
    #test_result = test_result.cpu().numpy() -> no need to detach stuff.. 
    len(test_result)
    test_result = scaler_test.inverse_transform(test_result.reshape(-1,1)).reshape(-1)
    truth = scaler_test.inverse_transform(truth.reshape(-1,1)).reshape(-1)

    print(test_result)
    pyplot.plot(test_result,color="red")
    pyplot.plot(truth,color="blue")
    pyplot.plot(test_result-truth,color="green")
    pyplot.grid(True, which='both')
    pyplot.axhline(y=0, color='k')
    pyplot.ylim([600,900])
    pyplot.show()
    pyplot.close()
    return test_result, truth, total_loss / i



# predict the next n steps based on the input data 
def predict_future(eval_model, data_source,steps):
    eval_model.eval() 
    total_loss = 0.
    test_result = torch.Tensor(0)    
    truth = torch.Tensor(0)
    data, _ = get_batch(data_source , 0 , 1)
    with torch.no_grad():
        for i in range(0, steps):            
            output = eval_model(data[-input_window:])
            # (seq-len , batch-size , features-num)
            # input : [ m,m+1,...,m+n ] -> [m+1,...,m+n+1]
            data = torch.cat((data, output[-1:])) # [m,m+1,..., m+n+1]

    data = data.cpu().view(-1)
    data = scaler_test.inverse_transform(data.reshape(-1,1)).reshape(-1)
    # I used this plot to visualize if the model pics up any long therm structure within the data.
    pyplot.plot(data,color="red")       
    pyplot.plot(data[:input_window],color="blue")    
    pyplot.grid(True, which='both')
    #pyplot.ylim([700,800])
    pyplot.axhline(y=0, color='k')
    #pyplot.savefig('graph/transformer-future%d.png'%steps)
    pyplot.show()
    pyplot.close()


def evaluate(eval_model, data_source):
    eval_model.eval() # Turn on the evaluation mode
    total_loss = 0.
    eval_batch_size = 256
    with torch.no_grad():
        # for i in range(0, len(data_source) - 1, eval_batch_size): # Now len-1 is not necessary
        for i in range(0, len(data_source), eval_batch_size):
            data, targets = get_batch(data_source, i,eval_batch_size)
            output = eval_model(data)            
            total_loss += len(data[0]) * criterion(output, targets).cpu().item()
    return total_loss / len(data_source)

from function_file.ML_functions import make_dataframe
_, df = make_dataframe(60,20)
train_data, val_data = get_data(df)
model = TransAm().to(device)

criterion = nn.MSELoss()
lr = 0.001
#optimizer = torch.optim.SGD(model.parameters(), lr=lr)
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=0.95)

best_val_loss = float("inf")
epochs = 100 # The number of epochs
best_model = None

for epoch in range(1, epochs + 1):
    epoch_start_time = time.time()
    train(train_data)
    if ( epoch % 5== 0 ):
        test_result, truth, val_loss = plot_and_loss(model, val_data)
        #predict_future(model, val_data,5000)
    else:
        val_loss = evaluate(model, val_data)
   
    print('-' * 89)
    print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.5f} | valid ppl {:8.2f}'.format(epoch, (time.time() - epoch_start_time),
                                     val_loss, math.exp(val_loss)))
    print('-' * 89)

    #if val_loss < best_val_loss:
    #    best_val_loss = val_loss
    #    best_model = model

    scheduler.step() 

#src = torch.rand(input_window, batch_size, 1) # (source sequence length,batch size,feature number) 
#out = model(src)
#
#print(out)
#print(out.shape)
# Out:
# | epoch   1 |   207/ 1038 batches | lr 0.001000 | 14.99 ms | loss 0.72285 | ppl     2.06
# | epoch   1 |   414/ 1038 batches | lr 0.001000 | 14.59 ms | loss 0.00225 | ppl     1.00
# | epoch   1 |   621/ 1038 batches | lr 0.001000 | 14.26 ms | loss 0.00127 | ppl     1.00
# | epoch   1 |   828/ 1038 batches | lr 0.001000 | 14.27 ms | loss 0.00106 | ppl     1.00
# | epoch   1 |  1035/ 1038 batches | lr 0.001000 | 14.26 ms | loss 0.00140 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   1 | time: 16.80s | valid loss 0.26793 | valid ppl     1.31
# -----------------------------------------------------------------------------------------
# | epoch   2 |   207/ 1038 batches | lr 0.000902 | 14.75 ms | loss 0.01365 | ppl     1.01
# | epoch   2 |   414/ 1038 batches | lr 0.000902 | 14.34 ms | loss 0.00113 | ppl     1.00
# | epoch   2 |   621/ 1038 batches | lr 0.000902 | 14.26 ms | loss 0.00072 | ppl     1.00
# | epoch   2 |   828/ 1038 batches | lr 0.000902 | 14.67 ms | loss 0.00053 | ppl     1.00
# | epoch   2 |  1035/ 1038 batches | lr 0.000902 | 14.34 ms | loss 0.00097 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   2 | time: 16.76s | valid loss 0.35998 | valid ppl     1.43
# -----------------------------------------------------------------------------------------
# | epoch   3 |   207/ 1038 batches | lr 0.000857 | 14.42 ms | loss 0.02471 | ppl     1.03
# | epoch   3 |   414/ 1038 batches | lr 0.000857 | 14.34 ms | loss 0.00087 | ppl     1.00
# | epoch   3 |   621/ 1038 batches | lr 0.000857 | 14.67 ms | loss 0.00060 | ppl     1.00
# | epoch   3 |   828/ 1038 batches | lr 0.000857 | 14.35 ms | loss 0.00121 | ppl     1.00
# | epoch   3 |  1035/ 1038 batches | lr 0.000857 | 14.34 ms | loss 0.00114 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   3 | time: 16.71s | valid loss 0.36517 | valid ppl     1.44
# -----------------------------------------------------------------------------------------
# | epoch   4 |   207/ 1038 batches | lr 0.000815 | 14.75 ms | loss 0.03547 | ppl     1.04
# | epoch   4 |   414/ 1038 batches | lr 0.000815 | 14.34 ms | loss 0.00105 | ppl     1.00
# | epoch   4 |   621/ 1038 batches | lr 0.000815 | 14.34 ms | loss 0.00081 | ppl     1.00
# | epoch   4 |   828/ 1038 batches | lr 0.000815 | 14.34 ms | loss 0.00114 | ppl     1.00
# | epoch   4 |  1035/ 1038 batches | lr 0.000815 | 14.59 ms | loss 0.00112 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   4 | time: 16.78s | valid loss 0.35402 | valid ppl     1.42
# -----------------------------------------------------------------------------------------
# | epoch   5 |   207/ 1038 batches | lr 0.000774 | 14.55 ms | loss 0.03862 | ppl     1.04
# | epoch   5 |   414/ 1038 batches | lr 0.000774 | 14.49 ms | loss 0.00128 | ppl     1.00
# | epoch   5 |   621/ 1038 batches | lr 0.000774 | 14.50 ms | loss 0.00095 | ppl     1.00
# | epoch   5 |   828/ 1038 batches | lr 0.000774 | 14.88 ms | loss 0.00088 | ppl     1.00
# | epoch   5 |  1035/ 1038 batches | lr 0.000774 | 14.76 ms | loss 0.00133 | ppl     1.00
# [893.46258061 893.48018135 893.47868238 ... 893.85197273 893.85170679
#  893.85219032]
# -----------------------------------------------------------------------------------------
# | end of epoch   5 | time: 178.87s | valid loss 0.33560 | valid ppl     1.40
# -----------------------------------------------------------------------------------------
# | epoch   6 |   207/ 1038 batches | lr 0.000735 | 15.32 ms | loss 0.04545 | ppl     1.05
# | epoch   6 |   414/ 1038 batches | lr 0.000735 | 15.13 ms | loss 0.00101 | ppl     1.00
# | epoch   6 |   621/ 1038 batches | lr 0.000735 | 14.45 ms | loss 0.00116 | ppl     1.00
# | epoch   6 |   828/ 1038 batches | lr 0.000735 | 14.94 ms | loss 0.00084 | ppl     1.00
# | epoch   6 |  1035/ 1038 batches | lr 0.000735 | 14.36 ms | loss 0.00149 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   6 | time: 17.18s | valid loss 0.33636 | valid ppl     1.40
# -----------------------------------------------------------------------------------------
# | epoch   7 |   207/ 1038 batches | lr 0.000698 | 14.64 ms | loss 0.04774 | ppl     1.05
# | epoch   7 |   414/ 1038 batches | lr 0.000698 | 14.10 ms | loss 0.00097 | ppl     1.00
# | epoch   7 |   621/ 1038 batches | lr 0.000698 | 14.26 ms | loss 0.00116 | ppl     1.00
# | epoch   7 |   828/ 1038 batches | lr 0.000698 | 14.85 ms | loss 0.00113 | ppl     1.00
# | epoch   7 |  1035/ 1038 batches | lr 0.000698 | 14.79 ms | loss 0.00139 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   7 | time: 16.90s | valid loss 0.31932 | valid ppl     1.38
# -----------------------------------------------------------------------------------------
# | epoch   8 |   207/ 1038 batches | lr 0.000663 | 14.47 ms | loss 0.04440 | ppl     1.05
# | epoch   8 |   414/ 1038 batches | lr 0.000663 | 14.44 ms | loss 0.00094 | ppl     1.00
# | epoch   8 |   621/ 1038 batches | lr 0.000663 | 14.96 ms | loss 0.00096 | ppl     1.00
# | epoch   8 |   828/ 1038 batches | lr 0.000663 | 14.21 ms | loss 0.00082 | ppl     1.00
# | epoch   8 |  1035/ 1038 batches | lr 0.000663 | 14.18 ms | loss 0.00109 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   8 | time: 16.73s | valid loss 0.33320 | valid ppl     1.40
# -----------------------------------------------------------------------------------------
# | epoch   9 |   207/ 1038 batches | lr 0.000630 | 14.67 ms | loss 0.03616 | ppl     1.04
# | epoch   9 |   414/ 1038 batches | lr 0.000630 | 14.19 ms | loss 0.00090 | ppl     1.00
# | epoch   9 |   621/ 1038 batches | lr 0.000630 | 14.17 ms | loss 0.00093 | ppl     1.00
# | epoch   9 |   828/ 1038 batches | lr 0.000630 | 14.21 ms | loss 0.00080 | ppl     1.00
# | epoch   9 |  1035/ 1038 batches | lr 0.000630 | 14.54 ms | loss 0.00105 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch   9 | time: 16.63s | valid loss 0.33960 | valid ppl     1.40
# -----------------------------------------------------------------------------------------
# | epoch  10 |   207/ 1038 batches | lr 0.000599 | 14.26 ms | loss 0.07312 | ppl     1.08
# | epoch  10 |   414/ 1038 batches | lr 0.000599 | 14.27 ms | loss 0.00093 | ppl     1.00
# | epoch  10 |   621/ 1038 batches | lr 0.000599 | 14.50 ms | loss 0.00084 | ppl     1.00
# | epoch  10 |   828/ 1038 batches | lr 0.000599 | 14.19 ms | loss 0.00075 | ppl     1.00
# | epoch  10 |  1035/ 1038 batches | lr 0.000599 | 14.30 ms | loss 0.00104 | ppl     1.00
# [888.83643975 888.88310104 888.8976555  ... 889.5405901  889.54073516
#  889.53971973]
# -----------------------------------------------------------------------------------------
# | end of epoch  10 | time: 178.41s | valid loss 0.31113 | valid ppl     1.36
# -----------------------------------------------------------------------------------------
# | epoch  11 |   207/ 1038 batches | lr 0.000569 | 15.26 ms | loss 0.07578 | ppl     1.08
# | epoch  11 |   414/ 1038 batches | lr 0.000569 | 14.95 ms | loss 0.00096 | ppl     1.00
# | epoch  11 |   621/ 1038 batches | lr 0.000569 | 14.30 ms | loss 0.00082 | ppl     1.00
# | epoch  11 |   828/ 1038 batches | lr 0.000569 | 14.34 ms | loss 0.00075 | ppl     1.00
# | epoch  11 |  1035/ 1038 batches | lr 0.000569 | 14.74 ms | loss 0.00104 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  11 | time: 17.10s | valid loss 0.30220 | valid ppl     1.35
# -----------------------------------------------------------------------------------------
# | epoch  12 |   207/ 1038 batches | lr 0.000540 | 14.68 ms | loss 0.07574 | ppl     1.08
# | epoch  12 |   414/ 1038 batches | lr 0.000540 | 14.50 ms | loss 0.00091 | ppl     1.00
# | epoch  12 |   621/ 1038 batches | lr 0.000540 | 14.42 ms | loss 0.00079 | ppl     1.00
# | epoch  12 |   828/ 1038 batches | lr 0.000540 | 14.73 ms | loss 0.00071 | ppl     1.00
# | epoch  12 |  1035/ 1038 batches | lr 0.000540 | 14.39 ms | loss 0.00100 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  12 | time: 16.86s | valid loss 0.29001 | valid ppl     1.34
# -----------------------------------------------------------------------------------------
# | epoch  13 |   207/ 1038 batches | lr 0.000513 | 14.45 ms | loss 0.07377 | ppl     1.08
# | epoch  13 |   414/ 1038 batches | lr 0.000513 | 14.89 ms | loss 0.00091 | ppl     1.00
# | epoch  13 |   621/ 1038 batches | lr 0.000513 | 14.36 ms | loss 0.00089 | ppl     1.00
# | epoch  13 |   828/ 1038 batches | lr 0.000513 | 14.41 ms | loss 0.00092 | ppl     1.00
# | epoch  13 |  1035/ 1038 batches | lr 0.000513 | 14.50 ms | loss 0.00099 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  13 | time: 16.84s | valid loss 0.29597 | valid ppl     1.34
# -----------------------------------------------------------------------------------------
# | epoch  14 |   207/ 1038 batches | lr 0.000488 | 15.14 ms | loss 0.07319 | ppl     1.08
# | epoch  14 |   414/ 1038 batches | lr 0.000488 | 14.82 ms | loss 0.00090 | ppl     1.00
# | epoch  14 |   621/ 1038 batches | lr 0.000488 | 14.63 ms | loss 0.00083 | ppl     1.00
# | epoch  14 |   828/ 1038 batches | lr 0.000488 | 15.03 ms | loss 0.00116 | ppl     1.00
# | epoch  14 |  1035/ 1038 batches | lr 0.000488 | 14.51 ms | loss 0.00093 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  14 | time: 17.23s | valid loss 0.25975 | valid ppl     1.30
# -----------------------------------------------------------------------------------------
# | epoch  15 |   207/ 1038 batches | lr 0.000463 | 14.42 ms | loss 0.06574 | ppl     1.07
# | epoch  15 |   414/ 1038 batches | lr 0.000463 | 14.26 ms | loss 0.00080 | ppl     1.00
# | epoch  15 |   621/ 1038 batches | lr 0.000463 | 14.78 ms | loss 0.00077 | ppl     1.00
# | epoch  15 |   828/ 1038 batches | lr 0.000463 | 14.31 ms | loss 0.00104 | ppl     1.00
# | epoch  15 |  1035/ 1038 batches | lr 0.000463 | 14.42 ms | loss 0.00078 | ppl     1.00
# [870.73017758 870.7806709  870.75682045 ... 885.48695671 885.47687497
#  885.47486829]
# -----------------------------------------------------------------------------------------
# | end of epoch  15 | time: 182.29s | valid loss 0.23348 | valid ppl     1.26
# -----------------------------------------------------------------------------------------
# | epoch  16 |   207/ 1038 batches | lr 0.000440 | 15.55 ms | loss 0.05361 | ppl     1.06
# | epoch  16 |   414/ 1038 batches | lr 0.000440 | 14.28 ms | loss 0.00068 | ppl     1.00
# | epoch  16 |   621/ 1038 batches | lr 0.000440 | 14.33 ms | loss 0.00064 | ppl     1.00
# | epoch  16 |   828/ 1038 batches | lr 0.000440 | 14.26 ms | loss 0.00081 | ppl     1.00
# | epoch  16 |  1035/ 1038 batches | lr 0.000440 | 14.99 ms | loss 0.00062 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  16 | time: 17.08s | valid loss 0.19241 | valid ppl     1.21
# -----------------------------------------------------------------------------------------
# | epoch  17 |   207/ 1038 batches | lr 0.000418 | 14.51 ms | loss 0.03743 | ppl     1.04
# | epoch  17 |   414/ 1038 batches | lr 0.000418 | 14.60 ms | loss 0.00049 | ppl     1.00
# | epoch  17 |   621/ 1038 batches | lr 0.000418 | 14.66 ms | loss 0.00046 | ppl     1.00
# | epoch  17 |   828/ 1038 batches | lr 0.000418 | 14.83 ms | loss 0.00049 | ppl     1.00
# | epoch  17 |  1035/ 1038 batches | lr 0.000418 | 14.34 ms | loss 0.00052 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  17 | time: 16.90s | valid loss 0.12821 | valid ppl     1.14
# -----------------------------------------------------------------------------------------
# | epoch  18 |   207/ 1038 batches | lr 0.000397 | 14.44 ms | loss 0.02645 | ppl     1.03
# | epoch  18 |   414/ 1038 batches | lr 0.000397 | 14.65 ms | loss 0.00048 | ppl     1.00
# | epoch  18 |   621/ 1038 batches | lr 0.000397 | 14.34 ms | loss 0.00039 | ppl     1.00
# | epoch  18 |   828/ 1038 batches | lr 0.000397 | 14.58 ms | loss 0.00040 | ppl     1.00
# | epoch  18 |  1035/ 1038 batches | lr 0.000397 | 14.46 ms | loss 0.00043 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  18 | time: 16.83s | valid loss 0.09690 | valid ppl     1.10
# -----------------------------------------------------------------------------------------
# | epoch  19 |   207/ 1038 batches | lr 0.000377 | 14.98 ms | loss 0.01779 | ppl     1.02
# | epoch  19 |   414/ 1038 batches | lr 0.000377 | 14.43 ms | loss 0.00037 | ppl     1.00
# | epoch  19 |   621/ 1038 batches | lr 0.000377 | 14.34 ms | loss 0.00031 | ppl     1.00
# | epoch  19 |   828/ 1038 batches | lr 0.000377 | 14.65 ms | loss 0.00033 | ppl     1.00
# | epoch  19 |  1035/ 1038 batches | lr 0.000377 | 14.45 ms | loss 0.00042 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  19 | time: 16.88s | valid loss 0.07591 | valid ppl     1.08
# -----------------------------------------------------------------------------------------
# | epoch  20 |   207/ 1038 batches | lr 0.000358 | 14.42 ms | loss 0.01197 | ppl     1.01
# | epoch  20 |   414/ 1038 batches | lr 0.000358 | 14.51 ms | loss 0.00030 | ppl     1.00
# | epoch  20 |   621/ 1038 batches | lr 0.000358 | 15.13 ms | loss 0.00022 | ppl     1.00
# | epoch  20 |   828/ 1038 batches | lr 0.000358 | 14.61 ms | loss 0.00029 | ppl     1.00
# | epoch  20 |  1035/ 1038 batches | lr 0.000358 | 14.44 ms | loss 0.00041 | ppl     1.00
# [805.98753613 805.99773875 806.03865805 ... 886.17282937 886.16417406
#  886.16035412]
# -----------------------------------------------------------------------------------------
# | end of epoch  20 | time: 186.33s | valid loss 0.05454 | valid ppl     1.06
# -----------------------------------------------------------------------------------------
# | epoch  21 |   207/ 1038 batches | lr 0.000341 | 15.17 ms | loss 0.00825 | ppl     1.01
# | epoch  21 |   414/ 1038 batches | lr 0.000341 | 14.13 ms | loss 0.00024 | ppl     1.00
# | epoch  21 |   621/ 1038 batches | lr 0.000341 | 14.23 ms | loss 0.00020 | ppl     1.00
# | epoch  21 |   828/ 1038 batches | lr 0.000341 | 14.58 ms | loss 0.00026 | ppl     1.00
# | epoch  21 |  1035/ 1038 batches | lr 0.000341 | 14.70 ms | loss 0.00042 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  21 | time: 16.85s | valid loss 0.04525 | valid ppl     1.05
# -----------------------------------------------------------------------------------------
# | epoch  22 |   207/ 1038 batches | lr 0.000324 | 14.42 ms | loss 0.00582 | ppl     1.01
# | epoch  22 |   414/ 1038 batches | lr 0.000324 | 14.53 ms | loss 0.00022 | ppl     1.00
# | epoch  22 |   621/ 1038 batches | lr 0.000324 | 14.73 ms | loss 0.00017 | ppl     1.00
# | epoch  22 |   828/ 1038 batches | lr 0.000324 | 14.51 ms | loss 0.00024 | ppl     1.00
# | epoch  22 |  1035/ 1038 batches | lr 0.000324 | 14.42 ms | loss 0.00041 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  22 | time: 16.86s | valid loss 0.03780 | valid ppl     1.04
# -----------------------------------------------------------------------------------------
# | epoch  23 |   207/ 1038 batches | lr 0.000307 | 14.21 ms | loss 0.00490 | ppl     1.00
# | epoch  23 |   414/ 1038 batches | lr 0.000307 | 15.09 ms | loss 0.00018 | ppl     1.00
# | epoch  23 |   621/ 1038 batches | lr 0.000307 | 14.73 ms | loss 0.00015 | ppl     1.00
# | epoch  23 |   828/ 1038 batches | lr 0.000307 | 14.96 ms | loss 0.00022 | ppl     1.00
# | epoch  23 |  1035/ 1038 batches | lr 0.000307 | 15.17 ms | loss 0.00041 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  23 | time: 17.22s | valid loss 0.02871 | valid ppl     1.03
# -----------------------------------------------------------------------------------------
# | epoch  24 |   207/ 1038 batches | lr 0.000292 | 14.82 ms | loss 0.00357 | ppl     1.00
# | epoch  24 |   414/ 1038 batches | lr 0.000292 | 14.89 ms | loss 0.00016 | ppl     1.00
# | epoch  24 |   621/ 1038 batches | lr 0.000292 | 14.50 ms | loss 0.00014 | ppl     1.00
# | epoch  24 |   828/ 1038 batches | lr 0.000292 | 14.85 ms | loss 0.00021 | ppl     1.00
# | epoch  24 |  1035/ 1038 batches | lr 0.000292 | 14.36 ms | loss 0.00039 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  24 | time: 17.03s | valid loss 0.02645 | valid ppl     1.03
# -----------------------------------------------------------------------------------------
# | epoch  25 |   207/ 1038 batches | lr 0.000277 | 14.68 ms | loss 0.00310 | ppl     1.00
# | epoch  25 |   414/ 1038 batches | lr 0.000277 | 14.42 ms | loss 0.00014 | ppl     1.00
# | epoch  25 |   621/ 1038 batches | lr 0.000277 | 14.80 ms | loss 0.00012 | ppl     1.00
# | epoch  25 |   828/ 1038 batches | lr 0.000277 | 14.34 ms | loss 0.00020 | ppl     1.00
# | epoch  25 |  1035/ 1038 batches | lr 0.000277 | 14.28 ms | loss 0.00037 | ppl     1.00
# [781.53666172 781.74545892 781.85901148 ... 887.54201195 887.55673564
#  887.56766357]
# -----------------------------------------------------------------------------------------
# | end of epoch  25 | time: 170.77s | valid loss 0.02267 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  26 |   207/ 1038 batches | lr 0.000264 | 15.44 ms | loss 0.00261 | ppl     1.00
# | epoch  26 |   414/ 1038 batches | lr 0.000264 | 14.30 ms | loss 0.00013 | ppl     1.00
# | epoch  26 |   621/ 1038 batches | lr 0.000264 | 14.68 ms | loss 0.00010 | ppl     1.00
# | epoch  26 |   828/ 1038 batches | lr 0.000264 | 14.30 ms | loss 0.00019 | ppl     1.00
# | epoch  26 |  1035/ 1038 batches | lr 0.000264 | 14.70 ms | loss 0.00036 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  26 | time: 16.98s | valid loss 0.01891 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  27 |   207/ 1038 batches | lr 0.000250 | 14.26 ms | loss 0.00212 | ppl     1.00
# | epoch  27 |   414/ 1038 batches | lr 0.000250 | 14.23 ms | loss 0.00011 | ppl     1.00
# | epoch  27 |   621/ 1038 batches | lr 0.000250 | 14.62 ms | loss 0.00010 | ppl     1.00
# | epoch  27 |   828/ 1038 batches | lr 0.000250 | 14.32 ms | loss 0.00018 | ppl     1.00
# | epoch  27 |  1035/ 1038 batches | lr 0.000250 | 13.98 ms | loss 0.00034 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  27 | time: 16.54s | valid loss 0.01779 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  28 |   207/ 1038 batches | lr 0.000238 | 14.08 ms | loss 0.00184 | ppl     1.00
# | epoch  28 |   414/ 1038 batches | lr 0.000238 | 14.31 ms | loss 0.00011 | ppl     1.00
# | epoch  28 |   621/ 1038 batches | lr 0.000238 | 13.99 ms | loss 0.00009 | ppl     1.00
# | epoch  28 |   828/ 1038 batches | lr 0.000238 | 13.99 ms | loss 0.00017 | ppl     1.00
# | epoch  28 |  1035/ 1038 batches | lr 0.000238 | 14.34 ms | loss 0.00034 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  28 | time: 16.39s | valid loss 0.01625 | valid ppl     1.02
# -----------------------------------------------------------------------------------------
# | epoch  29 |   207/ 1038 batches | lr 0.000226 | 14.01 ms | loss 0.00165 | ppl     1.00
# | epoch  29 |   414/ 1038 batches | lr 0.000226 | 13.98 ms | loss 0.00010 | ppl     1.00
# | epoch  29 |   621/ 1038 batches | lr 0.000226 | 13.97 ms | loss 0.00009 | ppl     1.00
# | epoch  29 |   828/ 1038 batches | lr 0.000226 | 14.39 ms | loss 0.00017 | ppl     1.00
# | epoch  29 |  1035/ 1038 batches | lr 0.000226 | 14.05 ms | loss 0.00033 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  29 | time: 16.34s | valid loss 0.01369 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  30 |   207/ 1038 batches | lr 0.000215 | 14.02 ms | loss 0.00139 | ppl     1.00
# | epoch  30 |   414/ 1038 batches | lr 0.000215 | 14.38 ms | loss 0.00010 | ppl     1.00
# | epoch  30 |   621/ 1038 batches | lr 0.000215 | 14.05 ms | loss 0.00009 | ppl     1.00
# | epoch  30 |   828/ 1038 batches | lr 0.000215 | 14.08 ms | loss 0.00016 | ppl     1.00
# | epoch  30 |  1035/ 1038 batches | lr 0.000215 | 14.11 ms | loss 0.00030 | ppl     1.00
# [771.64704838 771.8358332  771.97332687 ... 885.82884135 885.85183352
#  885.88742182]
# -----------------------------------------------------------------------------------------
# | end of epoch  30 | time: 179.27s | valid loss 0.01313 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  31 |   207/ 1038 batches | lr 0.000204 | 15.18 ms | loss 0.00133 | ppl     1.00
# | epoch  31 |   414/ 1038 batches | lr 0.000204 | 14.24 ms | loss 0.00009 | ppl     1.00
# | epoch  31 |   621/ 1038 batches | lr 0.000204 | 14.14 ms | loss 0.00008 | ppl     1.00
# | epoch  31 |   828/ 1038 batches | lr 0.000204 | 14.19 ms | loss 0.00015 | ppl     1.00
# | epoch  31 |  1035/ 1038 batches | lr 0.000204 | 14.77 ms | loss 0.00030 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  31 | time: 16.82s | valid loss 0.01277 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  32 |   207/ 1038 batches | lr 0.000194 | 14.28 ms | loss 0.00118 | ppl     1.00
# | epoch  32 |   414/ 1038 batches | lr 0.000194 | 14.20 ms | loss 0.00009 | ppl     1.00
# | epoch  32 |   621/ 1038 batches | lr 0.000194 | 14.49 ms | loss 0.00008 | ppl     1.00
# | epoch  32 |   828/ 1038 batches | lr 0.000194 | 14.22 ms | loss 0.00015 | ppl     1.00
# | epoch  32 |  1035/ 1038 batches | lr 0.000194 | 14.07 ms | loss 0.00030 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  32 | time: 16.55s | valid loss 0.01145 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  33 |   207/ 1038 batches | lr 0.000184 | 14.55 ms | loss 0.00109 | ppl     1.00
# | epoch  33 |   414/ 1038 batches | lr 0.000184 | 14.56 ms | loss 0.00008 | ppl     1.00
# | epoch  33 |   621/ 1038 batches | lr 0.000184 | 14.19 ms | loss 0.00008 | ppl     1.00
# | epoch  33 |   828/ 1038 batches | lr 0.000184 | 14.19 ms | loss 0.00014 | ppl     1.00
# | epoch  33 |  1035/ 1038 batches | lr 0.000184 | 14.49 ms | loss 0.00028 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  33 | time: 16.70s | valid loss 0.01007 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  34 |   207/ 1038 batches | lr 0.000175 | 14.18 ms | loss 0.00092 | ppl     1.00
# | epoch  34 |   414/ 1038 batches | lr 0.000175 | 14.11 ms | loss 0.00008 | ppl     1.00
# | epoch  34 |   621/ 1038 batches | lr 0.000175 | 14.12 ms | loss 0.00007 | ppl     1.00
# | epoch  34 |   828/ 1038 batches | lr 0.000175 | 14.45 ms | loss 0.00013 | ppl     1.00
# | epoch  34 |  1035/ 1038 batches | lr 0.000175 | 14.15 ms | loss 0.00028 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  34 | time: 16.51s | valid loss 0.00842 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  35 |   207/ 1038 batches | lr 0.000166 | 14.23 ms | loss 0.00078 | ppl     1.00
# | epoch  35 |   414/ 1038 batches | lr 0.000166 | 14.55 ms | loss 0.00007 | ppl     1.00
# | epoch  35 |   621/ 1038 batches | lr 0.000166 | 14.24 ms | loss 0.00007 | ppl     1.00
# | epoch  35 |   828/ 1038 batches | lr 0.000166 | 14.25 ms | loss 0.00013 | ppl     1.00
# | epoch  35 |  1035/ 1038 batches | lr 0.000166 | 14.28 ms | loss 0.00026 | ppl     1.00
# [763.84858628 764.03376272 764.18518224 ... 885.62019525 885.64894151
#  885.69968869]
# -----------------------------------------------------------------------------------------
# | end of epoch  35 | time: 180.21s | valid loss 0.00786 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  36 |   207/ 1038 batches | lr 0.000158 | 15.27 ms | loss 0.00073 | ppl     1.00
# | epoch  36 |   414/ 1038 batches | lr 0.000158 | 13.93 ms | loss 0.00007 | ppl     1.00
# | epoch  36 |   621/ 1038 batches | lr 0.000158 | 13.86 ms | loss 0.00007 | ppl     1.00
# | epoch  36 |   828/ 1038 batches | lr 0.000158 | 14.38 ms | loss 0.00012 | ppl     1.00
# | epoch  36 |  1035/ 1038 batches | lr 0.000158 | 14.04 ms | loss 0.00025 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  36 | time: 16.57s | valid loss 0.00761 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  37 |   207/ 1038 batches | lr 0.000150 | 14.02 ms | loss 0.00071 | ppl     1.00
# | epoch  37 |   414/ 1038 batches | lr 0.000150 | 14.32 ms | loss 0.00007 | ppl     1.00
# | epoch  37 |   621/ 1038 batches | lr 0.000150 | 14.80 ms | loss 0.00006 | ppl     1.00
# | epoch  37 |   828/ 1038 batches | lr 0.000150 | 14.33 ms | loss 0.00011 | ppl     1.00
# | epoch  37 |  1035/ 1038 batches | lr 0.000150 | 14.47 ms | loss 0.00023 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  37 | time: 16.73s | valid loss 0.00651 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  38 |   207/ 1038 batches | lr 0.000142 | 14.98 ms | loss 0.00062 | ppl     1.00
# | epoch  38 |   414/ 1038 batches | lr 0.000142 | 14.44 ms | loss 0.00007 | ppl     1.00
# | epoch  38 |   621/ 1038 batches | lr 0.000142 | 14.42 ms | loss 0.00007 | ppl     1.00
# | epoch  38 |   828/ 1038 batches | lr 0.000142 | 14.58 ms | loss 0.00011 | ppl     1.00
# | epoch  38 |  1035/ 1038 batches | lr 0.000142 | 14.84 ms | loss 0.00023 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  38 | time: 16.99s | valid loss 0.00642 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  39 |   207/ 1038 batches | lr 0.000135 | 14.48 ms | loss 0.00060 | ppl     1.00
# | epoch  39 |   414/ 1038 batches | lr 0.000135 | 14.40 ms | loss 0.00007 | ppl     1.00
# | epoch  39 |   621/ 1038 batches | lr 0.000135 | 14.29 ms | loss 0.00006 | ppl     1.00
# | epoch  39 |   828/ 1038 batches | lr 0.000135 | 14.78 ms | loss 0.00010 | ppl     1.00
# | epoch  39 |  1035/ 1038 batches | lr 0.000135 | 14.49 ms | loss 0.00023 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  39 | time: 16.84s | valid loss 0.00575 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  40 |   207/ 1038 batches | lr 0.000129 | 14.43 ms | loss 0.00054 | ppl     1.00
# | epoch  40 |   414/ 1038 batches | lr 0.000129 | 14.82 ms | loss 0.00007 | ppl     1.00
# | epoch  40 |   621/ 1038 batches | lr 0.000129 | 14.42 ms | loss 0.00006 | ppl     1.00
# | epoch  40 |   828/ 1038 batches | lr 0.000129 | 14.49 ms | loss 0.00010 | ppl     1.00
# | epoch  40 |  1035/ 1038 batches | lr 0.000129 | 14.45 ms | loss 0.00022 | ppl     1.00
# [758.62145763 758.78926301 758.94698059 ... 884.92395073 884.93570067
#  885.00620032]
# -----------------------------------------------------------------------------------------
# | end of epoch  40 | time: 178.70s | valid loss 0.00512 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  41 |   207/ 1038 batches | lr 0.000122 | 15.15 ms | loss 0.00049 | ppl     1.00
# | epoch  41 |   414/ 1038 batches | lr 0.000122 | 14.18 ms | loss 0.00007 | ppl     1.00
# | epoch  41 |   621/ 1038 batches | lr 0.000122 | 14.18 ms | loss 0.00006 | ppl     1.00
# | epoch  41 |   828/ 1038 batches | lr 0.000122 | 14.52 ms | loss 0.00010 | ppl     1.00
# | epoch  41 |  1035/ 1038 batches | lr 0.000122 | 14.25 ms | loss 0.00021 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  41 | time: 16.75s | valid loss 0.00501 | valid ppl     1.01
# -----------------------------------------------------------------------------------------
# | epoch  42 |   207/ 1038 batches | lr 0.000116 | 14.35 ms | loss 0.00047 | ppl     1.00
# | epoch  42 |   414/ 1038 batches | lr 0.000116 | 14.18 ms | loss 0.00007 | ppl     1.00
# | epoch  42 |   621/ 1038 batches | lr 0.000116 | 14.51 ms | loss 0.00006 | ppl     1.00
# | epoch  42 |   828/ 1038 batches | lr 0.000116 | 14.26 ms | loss 0.00009 | ppl     1.00
# | epoch  42 |  1035/ 1038 batches | lr 0.000116 | 14.18 ms | loss 0.00020 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  42 | time: 16.60s | valid loss 0.00464 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  43 |   207/ 1038 batches | lr 0.000110 | 14.57 ms | loss 0.00045 | ppl     1.00
# | epoch  43 |   414/ 1038 batches | lr 0.000110 | 14.18 ms | loss 0.00007 | ppl     1.00
# | epoch  43 |   621/ 1038 batches | lr 0.000110 | 14.26 ms | loss 0.00006 | ppl     1.00
# | epoch  43 |   828/ 1038 batches | lr 0.000110 | 14.18 ms | loss 0.00009 | ppl     1.00
# | epoch  43 |  1035/ 1038 batches | lr 0.000110 | 14.59 ms | loss 0.00019 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  43 | time: 16.66s | valid loss 0.00409 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  44 |   207/ 1038 batches | lr 0.000105 | 14.24 ms | loss 0.00042 | ppl     1.00
# | epoch  44 |   414/ 1038 batches | lr 0.000105 | 14.20 ms | loss 0.00007 | ppl     1.00
# | epoch  44 |   621/ 1038 batches | lr 0.000105 | 14.37 ms | loss 0.00006 | ppl     1.00
# | epoch  44 |   828/ 1038 batches | lr 0.000105 | 14.64 ms | loss 0.00008 | ppl     1.00
# | epoch  44 |  1035/ 1038 batches | lr 0.000105 | 14.18 ms | loss 0.00019 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 16.66s | valid loss 0.00388 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  45 |   207/ 1038 batches | lr 0.000099 | 14.36 ms | loss 0.00041 | ppl     1.00
# | epoch  45 |   414/ 1038 batches | lr 0.000099 | 14.58 ms | loss 0.00007 | ppl     1.00
# | epoch  45 |   621/ 1038 batches | lr 0.000099 | 14.28 ms | loss 0.00006 | ppl     1.00
# | epoch  45 |   828/ 1038 batches | lr 0.000099 | 14.41 ms | loss 0.00008 | ppl     1.00
# | epoch  45 |  1035/ 1038 batches | lr 0.000099 | 14.34 ms | loss 0.00018 | ppl     1.00
# [754.84782827 755.00991582 755.20555478 ... 884.1488051  884.15974512
#  884.23144153]
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 177.33s | valid loss 0.00351 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  46 |   207/ 1038 batches | lr 0.000094 | 15.15 ms | loss 0.00038 | ppl     1.00
# | epoch  46 |   414/ 1038 batches | lr 0.000094 | 14.10 ms | loss 0.00007 | ppl     1.00
# | epoch  46 |   621/ 1038 batches | lr 0.000094 | 14.26 ms | loss 0.00006 | ppl     1.00
# | epoch  46 |   828/ 1038 batches | lr 0.000094 | 14.50 ms | loss 0.00008 | ppl     1.00
# | epoch  46 |  1035/ 1038 batches | lr 0.000094 | 14.34 ms | loss 0.00018 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  46 | time: 16.78s | valid loss 0.00318 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  47 |   207/ 1038 batches | lr 0.000090 | 14.25 ms | loss 0.00036 | ppl     1.00
# | epoch  47 |   414/ 1038 batches | lr 0.000090 | 14.20 ms | loss 0.00006 | ppl     1.00
# | epoch  47 |   621/ 1038 batches | lr 0.000090 | 14.57 ms | loss 0.00006 | ppl     1.00
# | epoch  47 |   828/ 1038 batches | lr 0.000090 | 14.18 ms | loss 0.00008 | ppl     1.00
# | epoch  47 |  1035/ 1038 batches | lr 0.000090 | 14.18 ms | loss 0.00016 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  47 | time: 16.55s | valid loss 0.00296 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  48 |   207/ 1038 batches | lr 0.000085 | 14.64 ms | loss 0.00036 | ppl     1.00
# | epoch  48 |   414/ 1038 batches | lr 0.000085 | 14.18 ms | loss 0.00006 | ppl     1.00
# | epoch  48 |   621/ 1038 batches | lr 0.000085 | 14.26 ms | loss 0.00006 | ppl     1.00
# | epoch  48 |   828/ 1038 batches | lr 0.000085 | 14.27 ms | loss 0.00008 | ppl     1.00
# | epoch  48 |  1035/ 1038 batches | lr 0.000085 | 14.50 ms | loss 0.00016 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  48 | time: 16.68s | valid loss 0.00270 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  49 |   207/ 1038 batches | lr 0.000081 | 14.26 ms | loss 0.00035 | ppl     1.00
# | epoch  49 |   414/ 1038 batches | lr 0.000081 | 14.26 ms | loss 0.00006 | ppl     1.00
# | epoch  49 |   621/ 1038 batches | lr 0.000081 | 14.26 ms | loss 0.00005 | ppl     1.00
# | epoch  49 |   828/ 1038 batches | lr 0.000081 | 14.59 ms | loss 0.00008 | ppl     1.00
# | epoch  49 |  1035/ 1038 batches | lr 0.000081 | 14.26 ms | loss 0.00016 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  49 | time: 16.66s | valid loss 0.00264 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  50 |   207/ 1038 batches | lr 0.000077 | 14.27 ms | loss 0.00033 | ppl     1.00
# | epoch  50 |   414/ 1038 batches | lr 0.000077 | 14.58 ms | loss 0.00006 | ppl     1.00
# | epoch  50 |   621/ 1038 batches | lr 0.000077 | 14.35 ms | loss 0.00005 | ppl     1.00
# | epoch  50 |   828/ 1038 batches | lr 0.000077 | 14.26 ms | loss 0.00007 | ppl     1.00
# | epoch  50 |  1035/ 1038 batches | lr 0.000077 | 14.26 ms | loss 0.00015 | ppl     1.00
# [751.78732491 751.9192035  752.13035795 ... 882.91729752 882.92936176
#  882.98558499]
# -----------------------------------------------------------------------------------------
# | end of epoch  50 | time: 179.82s | valid loss 0.00234 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  51 |   207/ 1038 batches | lr 0.000073 | 15.78 ms | loss 0.00032 | ppl     1.00
# | epoch  51 |   414/ 1038 batches | lr 0.000073 | 14.19 ms | loss 0.00006 | ppl     1.00
# | epoch  51 |   621/ 1038 batches | lr 0.000073 | 14.28 ms | loss 0.00005 | ppl     1.00
# | epoch  51 |   828/ 1038 batches | lr 0.000073 | 14.57 ms | loss 0.00007 | ppl     1.00
# | epoch  51 |  1035/ 1038 batches | lr 0.000073 | 14.26 ms | loss 0.00014 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  51 | time: 16.97s | valid loss 0.00233 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  52 |   207/ 1038 batches | lr 0.000069 | 14.68 ms | loss 0.00032 | ppl     1.00
# | epoch  52 |   414/ 1038 batches | lr 0.000069 | 14.73 ms | loss 0.00006 | ppl     1.00
# | epoch  52 |   621/ 1038 batches | lr 0.000069 | 15.40 ms | loss 0.00005 | ppl     1.00
# | epoch  52 |   828/ 1038 batches | lr 0.000069 | 14.69 ms | loss 0.00007 | ppl     1.00
# | epoch  52 |  1035/ 1038 batches | lr 0.000069 | 14.62 ms | loss 0.00014 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  52 | time: 17.20s | valid loss 0.00218 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  53 |   207/ 1038 batches | lr 0.000066 | 15.00 ms | loss 0.00031 | ppl     1.00
# | epoch  53 |   414/ 1038 batches | lr 0.000066 | 14.64 ms | loss 0.00006 | ppl     1.00
# | epoch  53 |   621/ 1038 batches | lr 0.000066 | 14.61 ms | loss 0.00005 | ppl     1.00
# | epoch  53 |   828/ 1038 batches | lr 0.000066 | 14.61 ms | loss 0.00007 | ppl     1.00
# | epoch  53 |  1035/ 1038 batches | lr 0.000066 | 14.95 ms | loss 0.00014 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  53 | time: 17.12s | valid loss 0.00210 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  54 |   207/ 1038 batches | lr 0.000063 | 14.69 ms | loss 0.00030 | ppl     1.00
# | epoch  54 |   414/ 1038 batches | lr 0.000063 | 14.57 ms | loss 0.00006 | ppl     1.00
# | epoch  54 |   621/ 1038 batches | lr 0.000063 | 14.55 ms | loss 0.00005 | ppl     1.00
# | epoch  54 |   828/ 1038 batches | lr 0.000063 | 14.98 ms | loss 0.00007 | ppl     1.00
# | epoch  54 |  1035/ 1038 batches | lr 0.000063 | 14.80 ms | loss 0.00013 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  54 | time: 17.09s | valid loss 0.00199 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  55 |   207/ 1038 batches | lr 0.000060 | 15.16 ms | loss 0.00029 | ppl     1.00
# | epoch  55 |   414/ 1038 batches | lr 0.000060 | 15.16 ms | loss 0.00006 | ppl     1.00
# | epoch  55 |   621/ 1038 batches | lr 0.000060 | 15.26 ms | loss 0.00005 | ppl     1.00
# | epoch  55 |   828/ 1038 batches | lr 0.000060 | 14.83 ms | loss 0.00007 | ppl     1.00
# | epoch  55 |  1035/ 1038 batches | lr 0.000060 | 15.68 ms | loss 0.00013 | ppl     1.00
# [750.46708834 750.58924784 750.80914221 ... 881.87979695 881.9078179
#  881.94285014]
# -----------------------------------------------------------------------------------------
# | end of epoch  55 | time: 181.39s | valid loss 0.00189 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  56 |   207/ 1038 batches | lr 0.000057 | 15.44 ms | loss 0.00028 | ppl     1.00
# | epoch  56 |   414/ 1038 batches | lr 0.000057 | 14.57 ms | loss 0.00006 | ppl     1.00
# | epoch  56 |   621/ 1038 batches | lr 0.000057 | 14.71 ms | loss 0.00005 | ppl     1.00
# | epoch  56 |   828/ 1038 batches | lr 0.000057 | 15.09 ms | loss 0.00007 | ppl     1.00
# | epoch  56 |  1035/ 1038 batches | lr 0.000057 | 14.79 ms | loss 0.00013 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  56 | time: 17.31s | valid loss 0.00186 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  57 |   207/ 1038 batches | lr 0.000054 | 14.86 ms | loss 0.00027 | ppl     1.00
# | epoch  57 |   414/ 1038 batches | lr 0.000054 | 14.58 ms | loss 0.00006 | ppl     1.00
# | epoch  57 |   621/ 1038 batches | lr 0.000054 | 15.02 ms | loss 0.00005 | ppl     1.00
# | epoch  57 |   828/ 1038 batches | lr 0.000054 | 14.59 ms | loss 0.00007 | ppl     1.00
# | epoch  57 |  1035/ 1038 batches | lr 0.000054 | 14.60 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  57 | time: 17.08s | valid loss 0.00176 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  58 |   207/ 1038 batches | lr 0.000051 | 15.18 ms | loss 0.00026 | ppl     1.00
# | epoch  58 |   414/ 1038 batches | lr 0.000051 | 14.67 ms | loss 0.00006 | ppl     1.00
# | epoch  58 |   621/ 1038 batches | lr 0.000051 | 14.69 ms | loss 0.00005 | ppl     1.00
# | epoch  58 |   828/ 1038 batches | lr 0.000051 | 14.64 ms | loss 0.00007 | ppl     1.00
# | epoch  58 |  1035/ 1038 batches | lr 0.000051 | 15.00 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  58 | time: 17.24s | valid loss 0.00168 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  59 |   207/ 1038 batches | lr 0.000048 | 14.68 ms | loss 0.00026 | ppl     1.00
# | epoch  59 |   414/ 1038 batches | lr 0.000048 | 14.69 ms | loss 0.00006 | ppl     1.00
# | epoch  59 |   621/ 1038 batches | lr 0.000048 | 15.04 ms | loss 0.00005 | ppl     1.00
# | epoch  59 |   828/ 1038 batches | lr 0.000048 | 14.73 ms | loss 0.00007 | ppl     1.00
# | epoch  59 |  1035/ 1038 batches | lr 0.000048 | 14.73 ms | loss 0.00012 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  59 | time: 17.16s | valid loss 0.00163 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  60 |   207/ 1038 batches | lr 0.000046 | 14.69 ms | loss 0.00025 | ppl     1.00
# | epoch  60 |   414/ 1038 batches | lr 0.000046 | 14.95 ms | loss 0.00006 | ppl     1.00
# | epoch  60 |   621/ 1038 batches | lr 0.000046 | 14.71 ms | loss 0.00005 | ppl     1.00
# | epoch  60 |   828/ 1038 batches | lr 0.000046 | 14.63 ms | loss 0.00007 | ppl     1.00
# | epoch  60 |  1035/ 1038 batches | lr 0.000046 | 14.62 ms | loss 0.00012 | ppl     1.00
# [749.27826496 749.42333806 749.65450488 ... 881.11428579 881.15166318
#  881.16566157]
# -----------------------------------------------------------------------------------------
# | end of epoch  60 | time: 178.33s | valid loss 0.00153 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  61 |   207/ 1038 batches | lr 0.000044 | 15.37 ms | loss 0.00025 | ppl     1.00
# | epoch  61 |   414/ 1038 batches | lr 0.000044 | 14.47 ms | loss 0.00006 | ppl     1.00
# | epoch  61 |   621/ 1038 batches | lr 0.000044 | 14.50 ms | loss 0.00004 | ppl     1.00
# | epoch  61 |   828/ 1038 batches | lr 0.000044 | 14.93 ms | loss 0.00007 | ppl     1.00
# | epoch  61 |  1035/ 1038 batches | lr 0.000044 | 14.49 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  61 | time: 17.11s | valid loss 0.00152 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  62 |   207/ 1038 batches | lr 0.000042 | 14.80 ms | loss 0.00024 | ppl     1.00
# | epoch  62 |   414/ 1038 batches | lr 0.000042 | 14.54 ms | loss 0.00005 | ppl     1.00
# | epoch  62 |   621/ 1038 batches | lr 0.000042 | 14.89 ms | loss 0.00004 | ppl     1.00
# | epoch  62 |   828/ 1038 batches | lr 0.000042 | 14.57 ms | loss 0.00007 | ppl     1.00
# | epoch  62 |  1035/ 1038 batches | lr 0.000042 | 14.56 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  62 | time: 17.04s | valid loss 0.00148 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  63 |   207/ 1038 batches | lr 0.000039 | 14.93 ms | loss 0.00024 | ppl     1.00
# | epoch  63 |   414/ 1038 batches | lr 0.000039 | 14.72 ms | loss 0.00005 | ppl     1.00
# | epoch  63 |   621/ 1038 batches | lr 0.000039 | 14.68 ms | loss 0.00004 | ppl     1.00
# | epoch  63 |   828/ 1038 batches | lr 0.000039 | 14.70 ms | loss 0.00007 | ppl     1.00
# | epoch  63 |  1035/ 1038 batches | lr 0.000039 | 15.07 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  63 | time: 17.21s | valid loss 0.00142 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  64 |   207/ 1038 batches | lr 0.000038 | 14.73 ms | loss 0.00023 | ppl     1.00
# | epoch  64 |   414/ 1038 batches | lr 0.000038 | 14.70 ms | loss 0.00005 | ppl     1.00
# | epoch  64 |   621/ 1038 batches | lr 0.000038 | 15.08 ms | loss 0.00004 | ppl     1.00
# | epoch  64 |   828/ 1038 batches | lr 0.000038 | 14.60 ms | loss 0.00007 | ppl     1.00
# | epoch  64 |  1035/ 1038 batches | lr 0.000038 | 14.55 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  64 | time: 17.09s | valid loss 0.00137 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  65 |   207/ 1038 batches | lr 0.000036 | 14.75 ms | loss 0.00023 | ppl     1.00
# | epoch  65 |   414/ 1038 batches | lr 0.000036 | 14.95 ms | loss 0.00005 | ppl     1.00
# | epoch  65 |   621/ 1038 batches | lr 0.000036 | 15.42 ms | loss 0.00004 | ppl     1.00
# | epoch  65 |   828/ 1038 batches | lr 0.000036 | 15.32 ms | loss 0.00007 | ppl     1.00
# | epoch  65 |  1035/ 1038 batches | lr 0.000036 | 15.08 ms | loss 0.00011 | ppl     1.00
# [748.64824683 748.81191797 749.04484969 ... 880.4187424  880.46120901
#  880.46489598]
# -----------------------------------------------------------------------------------------
# | end of epoch  65 | time: 193.04s | valid loss 0.00129 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  66 |   207/ 1038 batches | lr 0.000034 | 15.16 ms | loss 0.00023 | ppl     1.00
# | epoch  66 |   414/ 1038 batches | lr 0.000034 | 14.61 ms | loss 0.00005 | ppl     1.00
# | epoch  66 |   621/ 1038 batches | lr 0.000034 | 14.73 ms | loss 0.00004 | ppl     1.00
# | epoch  66 |   828/ 1038 batches | lr 0.000034 | 15.87 ms | loss 0.00007 | ppl     1.00
# | epoch  66 |  1035/ 1038 batches | lr 0.000034 | 14.81 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  66 | time: 17.42s | valid loss 0.00129 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  67 |   207/ 1038 batches | lr 0.000032 | 14.67 ms | loss 0.00022 | ppl     1.00
# | epoch  67 |   414/ 1038 batches | lr 0.000032 | 14.59 ms | loss 0.00005 | ppl     1.00
# | epoch  67 |   621/ 1038 batches | lr 0.000032 | 14.95 ms | loss 0.00004 | ppl     1.00
# | epoch  67 |   828/ 1038 batches | lr 0.000032 | 14.73 ms | loss 0.00007 | ppl     1.00
# | epoch  67 |  1035/ 1038 batches | lr 0.000032 | 14.65 ms | loss 0.00011 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  67 | time: 17.09s | valid loss 0.00126 | valid ppl     1.00
# ...
# | epoch  74 |   621/ 1038 batches | lr 0.000022 | 15.44 ms | loss 0.00004 | ppl     1.00
# | epoch  74 |   828/ 1038 batches | lr 0.000022 | 15.05 ms | loss 0.00007 | ppl     1.00
# | epoch  74 |  1035/ 1038 batches | lr 0.000022 | 14.96 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  74 | time: 17.58s | valid loss 0.00101 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  75 |   207/ 1038 batches | lr 0.000021 | 15.20 ms | loss 0.00020 | ppl     1.00
# | epoch  75 |   414/ 1038 batches | lr 0.000021 | 15.67 ms | loss 0.00005 | ppl     1.00
# | epoch  75 |   621/ 1038 batches | lr 0.000021 | 15.81 ms | loss 0.00004 | ppl     1.00
# | epoch  75 |   828/ 1038 batches | lr 0.000021 | 15.26 ms | loss 0.00007 | ppl     1.00
# | epoch  75 |  1035/ 1038 batches | lr 0.000021 | 15.35 ms | loss 0.00010 | ppl     1.00
# [748.03931695 748.23357178 748.46895746 ... 878.6203001  878.66552287
#  878.66494262]
# -----------------------------------------------------------------------------------------
# | end of epoch  75 | time: 183.70s | valid loss 0.00095 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  76 |   207/ 1038 batches | lr 0.000020 | 15.89 ms | loss 0.00020 | ppl     1.00
# | epoch  76 |   414/ 1038 batches | lr 0.000020 | 15.09 ms | loss 0.00005 | ppl     1.00
# | epoch  76 |   621/ 1038 batches | lr 0.000020 | 14.95 ms | loss 0.00004 | ppl     1.00
# | epoch  76 |   828/ 1038 batches | lr 0.000020 | 15.35 ms | loss 0.00007 | ppl     1.00
# | epoch  76 |  1035/ 1038 batches | lr 0.000020 | 15.00 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  76 | time: 17.70s | valid loss 0.00096 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  77 |   207/ 1038 batches | lr 0.000019 | 15.10 ms | loss 0.00020 | ppl     1.00
# | epoch  77 |   414/ 1038 batches | lr 0.000019 | 15.24 ms | loss 0.00005 | ppl     1.00
# | epoch  77 |   621/ 1038 batches | lr 0.000019 | 15.02 ms | loss 0.00004 | ppl     1.00
# | epoch  77 |   828/ 1038 batches | lr 0.000019 | 14.95 ms | loss 0.00007 | ppl     1.00
# | epoch  77 |  1035/ 1038 batches | lr 0.000019 | 15.03 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  77 | time: 17.51s | valid loss 0.00093 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  78 |   207/ 1038 batches | lr 0.000018 | 15.48 ms | loss 0.00020 | ppl     1.00
# | epoch  78 |   414/ 1038 batches | lr 0.000018 | 14.99 ms | loss 0.00006 | ppl     1.00
# | epoch  78 |   621/ 1038 batches | lr 0.000018 | 15.01 ms | loss 0.00004 | ppl     1.00
# | epoch  78 |   828/ 1038 batches | lr 0.000018 | 15.23 ms | loss 0.00007 | ppl     1.00
# | epoch  78 |  1035/ 1038 batches | lr 0.000018 | 16.17 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  78 | time: 17.99s | valid loss 0.00091 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  79 |   207/ 1038 batches | lr 0.000017 | 15.26 ms | loss 0.00020 | ppl     1.00
# | epoch  79 |   414/ 1038 batches | lr 0.000017 | 15.16 ms | loss 0.00006 | ppl     1.00
# | epoch  79 |   621/ 1038 batches | lr 0.000017 | 15.37 ms | loss 0.00004 | ppl     1.00
# | epoch  79 |   828/ 1038 batches | lr 0.000017 | 15.18 ms | loss 0.00007 | ppl     1.00
# | epoch  79 |  1035/ 1038 batches | lr 0.000017 | 15.43 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  79 | time: 17.72s | valid loss 0.00088 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  80 |   207/ 1038 batches | lr 0.000017 | 15.06 ms | loss 0.00020 | ppl     1.00
# | epoch  80 |   414/ 1038 batches | lr 0.000017 | 15.42 ms | loss 0.00006 | ppl     1.00
# | epoch  80 |   621/ 1038 batches | lr 0.000017 | 15.07 ms | loss 0.00004 | ppl     1.00
# | epoch  80 |   828/ 1038 batches | lr 0.000017 | 15.15 ms | loss 0.00007 | ppl     1.00
# | epoch  80 |  1035/ 1038 batches | lr 0.000017 | 15.45 ms | loss 0.00010 | ppl     1.00
# [747.7496301  747.95454692 748.19111726 ... 877.7298914  877.78000998
#  877.78297165]
# -----------------------------------------------------------------------------------------
# | end of epoch  80 | time: 182.84s | valid loss 0.00082 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  81 |   207/ 1038 batches | lr 0.000016 | 15.63 ms | loss 0.00020 | ppl     1.00
# | epoch  81 |   414/ 1038 batches | lr 0.000016 | 15.12 ms | loss 0.00006 | ppl     1.00
# | epoch  81 |   621/ 1038 batches | lr 0.000016 | 15.11 ms | loss 0.00004 | ppl     1.00
# | epoch  81 |   828/ 1038 batches | lr 0.000016 | 15.78 ms | loss 0.00007 | ppl     1.00
# | epoch  81 |  1035/ 1038 batches | lr 0.000016 | 15.20 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  81 | time: 17.97s | valid loss 0.00083 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  82 |   207/ 1038 batches | lr 0.000015 | 15.08 ms | loss 0.00019 | ppl     1.00
# | epoch  82 |   414/ 1038 batches | lr 0.000015 | 15.63 ms | loss 0.00006 | ppl     1.00
# | epoch  82 |   621/ 1038 batches | lr 0.000015 | 15.05 ms | loss 0.00004 | ppl     1.00
# | epoch  82 |   828/ 1038 batches | lr 0.000015 | 15.31 ms | loss 0.00007 | ppl     1.00
# | epoch  82 |  1035/ 1038 batches | lr 0.000015 | 15.32 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  82 | time: 17.74s | valid loss 0.00081 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  83 |   207/ 1038 batches | lr 0.000014 | 15.49 ms | loss 0.00019 | ppl     1.00
# | epoch  83 |   414/ 1038 batches | lr 0.000014 | 14.95 ms | loss 0.00006 | ppl     1.00
# | epoch  83 |   621/ 1038 batches | lr 0.000014 | 15.13 ms | loss 0.00004 | ppl     1.00
# | epoch  83 |   828/ 1038 batches | lr 0.000014 | 15.13 ms | loss 0.00007 | ppl     1.00
# | epoch  83 |  1035/ 1038 batches | lr 0.000014 | 15.48 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  83 | time: 17.69s | valid loss 0.00079 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  84 |   207/ 1038 batches | lr 0.000013 | 15.47 ms | loss 0.00019 | ppl     1.00
# | epoch  84 |   414/ 1038 batches | lr 0.000013 | 15.21 ms | loss 0.00006 | ppl     1.00
# | epoch  84 |   621/ 1038 batches | lr 0.000013 | 15.43 ms | loss 0.00004 | ppl     1.00
# | epoch  84 |   828/ 1038 batches | lr 0.000013 | 15.06 ms | loss 0.00007 | ppl     1.00
# | epoch  84 |  1035/ 1038 batches | lr 0.000013 | 15.01 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  84 | time: 17.69s | valid loss 0.00076 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  85 |   207/ 1038 batches | lr 0.000013 | 15.19 ms | loss 0.00019 | ppl     1.00
# | epoch  85 |   414/ 1038 batches | lr 0.000013 | 15.42 ms | loss 0.00006 | ppl     1.00
# | epoch  85 |   621/ 1038 batches | lr 0.000013 | 15.04 ms | loss 0.00004 | ppl     1.00
# | epoch  85 |   828/ 1038 batches | lr 0.000013 | 15.11 ms | loss 0.00007 | ppl     1.00
# | epoch  85 |  1035/ 1038 batches | lr 0.000013 | 15.46 ms | loss 0.00010 | ppl     1.00
# [747.51182674 747.72385155 747.96147358 ... 876.83572321 876.8895892
#  876.89519823]
# -----------------------------------------------------------------------------------------
# | end of epoch  85 | time: 184.88s | valid loss 0.00071 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  86 |   207/ 1038 batches | lr 0.000012 | 15.60 ms | loss 0.00019 | ppl     1.00
# | epoch  86 |   414/ 1038 batches | lr 0.000012 | 15.03 ms | loss 0.00006 | ppl     1.00
# | epoch  86 |   621/ 1038 batches | lr 0.000012 | 15.32 ms | loss 0.00004 | ppl     1.00
# | epoch  86 |   828/ 1038 batches | lr 0.000012 | 15.61 ms | loss 0.00007 | ppl     1.00
# | epoch  86 |  1035/ 1038 batches | lr 0.000012 | 15.63 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  86 | time: 17.93s | valid loss 0.00073 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  87 |   207/ 1038 batches | lr 0.000012 | 15.46 ms | loss 0.00019 | ppl     1.00
# | epoch  87 |   414/ 1038 batches | lr 0.000012 | 15.70 ms | loss 0.00006 | ppl     1.00
# | epoch  87 |   621/ 1038 batches | lr 0.000012 | 15.41 ms | loss 0.00003 | ppl     1.00
# | epoch  87 |   828/ 1038 batches | lr 0.000012 | 15.77 ms | loss 0.00006 | ppl     1.00
# | epoch  87 |  1035/ 1038 batches | lr 0.000012 | 15.29 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  87 | time: 18.01s | valid loss 0.00072 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  88 |   207/ 1038 batches | lr 0.000011 | 15.58 ms | loss 0.00020 | ppl     1.00
# | epoch  88 |   414/ 1038 batches | lr 0.000011 | 15.12 ms | loss 0.00006 | ppl     1.00
# | epoch  88 |   621/ 1038 batches | lr 0.000011 | 15.42 ms | loss 0.00003 | ppl     1.00
# | epoch  88 |   828/ 1038 batches | lr 0.000011 | 15.62 ms | loss 0.00006 | ppl     1.00
# | epoch  88 |  1035/ 1038 batches | lr 0.000011 | 15.98 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  88 | time: 17.95s | valid loss 0.00070 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  89 |   207/ 1038 batches | lr 0.000010 | 14.67 ms | loss 0.00020 | ppl     1.00
# | epoch  89 |   414/ 1038 batches | lr 0.000010 | 14.72 ms | loss 0.00006 | ppl     1.00
# | epoch  89 |   621/ 1038 batches | lr 0.000010 | 15.32 ms | loss 0.00003 | ppl     1.00
# | epoch  89 |   828/ 1038 batches | lr 0.000010 | 14.97 ms | loss 0.00006 | ppl     1.00
# | epoch  89 |  1035/ 1038 batches | lr 0.000010 | 14.77 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  89 | time: 17.28s | valid loss 0.00069 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  90 |   207/ 1038 batches | lr 0.000010 | 14.84 ms | loss 0.00020 | ppl     1.00
# | epoch  90 |   414/ 1038 batches | lr 0.000010 | 14.93 ms | loss 0.00006 | ppl     1.00
# | epoch  90 |   621/ 1038 batches | lr 0.000010 | 14.59 ms | loss 0.00003 | ppl     1.00
# | epoch  90 |   828/ 1038 batches | lr 0.000010 | 14.66 ms | loss 0.00006 | ppl     1.00
# | epoch  90 |  1035/ 1038 batches | lr 0.000010 | 15.02 ms | loss 0.00010 | ppl     1.00
# [747.38976998 747.60720436 747.84708088 ... 876.17974521 876.23810809
#  876.24695681]
# -----------------------------------------------------------------------------------------
# | end of epoch  90 | time: 181.02s | valid loss 0.00064 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  91 |   207/ 1038 batches | lr 0.000009 | 15.81 ms | loss 0.00019 | ppl     1.00
# | epoch  91 |   414/ 1038 batches | lr 0.000009 | 14.74 ms | loss 0.00006 | ppl     1.00
# | epoch  91 |   621/ 1038 batches | lr 0.000009 | 15.06 ms | loss 0.00003 | ppl     1.00
# | epoch  91 |   828/ 1038 batches | lr 0.000009 | 15.67 ms | loss 0.00006 | ppl     1.00
# | epoch  91 |  1035/ 1038 batches | lr 0.000009 | 15.26 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  91 | time: 17.83s | valid loss 0.00067 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  92 |   207/ 1038 batches | lr 0.000009 | 14.70 ms | loss 0.00020 | ppl     1.00
# | epoch  92 |   414/ 1038 batches | lr 0.000009 | 14.89 ms | loss 0.00006 | ppl     1.00
# | epoch  92 |   621/ 1038 batches | lr 0.000009 | 14.62 ms | loss 0.00003 | ppl     1.00
# | epoch  92 |   828/ 1038 batches | lr 0.000009 | 14.68 ms | loss 0.00006 | ppl     1.00
# | epoch  92 |  1035/ 1038 batches | lr 0.000009 | 14.74 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  92 | time: 17.09s | valid loss 0.00066 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  93 |   207/ 1038 batches | lr 0.000008 | 15.07 ms | loss 0.00020 | ppl     1.00
# | epoch  93 |   414/ 1038 batches | lr 0.000008 | 14.50 ms | loss 0.00006 | ppl     1.00
# | epoch  93 |   621/ 1038 batches | lr 0.000008 | 14.70 ms | loss 0.00003 | ppl     1.00
# | epoch  93 |   828/ 1038 batches | lr 0.000008 | 14.77 ms | loss 0.00006 | ppl     1.00
# | epoch  93 |  1035/ 1038 batches | lr 0.000008 | 14.94 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  93 | time: 17.17s | valid loss 0.00065 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  94 |   207/ 1038 batches | lr 0.000008 | 14.93 ms | loss 0.00020 | ppl     1.00
# | epoch  94 |   414/ 1038 batches | lr 0.000008 | 14.73 ms | loss 0.00006 | ppl     1.00
# | epoch  94 |   621/ 1038 batches | lr 0.000008 | 15.16 ms | loss 0.00003 | ppl     1.00
# | epoch  94 |   828/ 1038 batches | lr 0.000008 | 14.89 ms | loss 0.00006 | ppl     1.00
# | epoch  94 |  1035/ 1038 batches | lr 0.000008 | 15.20 ms | loss 0.00010 | ppl     1.00
# -----------------------------------------------------------------------------------------
# | end of epoch  94 | time: 17.43s | valid loss 0.00064 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  95 |   207/ 1038 batches | lr 0.000008 | 14.94 ms | loss 0.00020 | ppl     1.00
# | epoch  95 |   414/ 1038 batches | lr 0.000008 | 15.19 ms | loss 0.00006 | ppl     1.00
# | epoch  95 |   621/ 1038 batches | lr 0.000008 | 14.82 ms | loss 0.00003 | ppl     1.00
# | epoch  95 |   828/ 1038 batches | lr 0.000008 | 14.74 ms | loss 0.00006 | ppl     1.00
# | epoch  95 |  1035/ 1038 batches | lr 0.000008 | 15.11 ms | loss 0.00010 | ppl     1.00
# [747.39869124 747.62061041 747.8629288  ... 875.7480678  875.8073494
#  875.81738279]
# -----------------------------------------------------------------------------------------
# | end of epoch  95 | time: 180.68s | valid loss 0.00060 | valid ppl     1.00
# -----------------------------------------------------------------------------------------
# | epoch  96 |   207/ 1038 batches | lr 0.000007 | 15.32 ms | loss 0.00019 | ppl     1.00
# | epoch  96 |   414/ 1038 batches | lr 0.000007 | 14.68 ms | loss 0.00006 | ppl     1.00
# | epoch  96 |   621/ 1038 batches | lr 0.000007 | 14.58 ms | loss 0.00003 | ppl     1.00

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score
print("r2 : ", r2_score(truth, test_result))
print("MAE : ", mean_absolute_error(truth, test_result))
print("RMSE : ", mean_squared_error(truth, test_result)**0.5)
# Out:
# r2 :  0.9964860806938378
# MAE :  1.8659677183204646
# RMSE :  2.394677566453939
